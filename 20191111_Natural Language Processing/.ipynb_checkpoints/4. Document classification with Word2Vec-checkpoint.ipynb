# %% [markdown]
# ## Unsupervised Learning
#
# * 의미가 비슷한 단어의 벡터는 가까운 곳에 몰려있다
# * 가까운곳의 기준? 유클리디안 거리!
#
#
# * 유클리디안 거리 행렬 구축
# * 가중치 행렬로 문장별 스코어 구하기 -> Document-Term Matrix와 내적

# %% [markdown]
# ## 임베딩 읽어들이기

# %%
def load_word_embeddings(path, num_vecs=30000):
    embeddings, vocab = [], []
    f = open(path, "r", encoding="utf-8").readlines()[1:num_vecs + 1]
    for line in f:
        splited_line = line.strip().split(" ")
        word = splited_line[0]
        vec = [float(el) for el in splited_line[1:]]
        vocab.append(word)
        embeddings.append(vec)
    word_to_index = {word: idx for idx, word in enumerate(vocab)}
    index_to_word = {idx: word for idx, word in enumerate(vocab)}
    vocab_size = len(vocab)
    return embeddings, vocab, word_to_index, index_to_word, vocab_size

# %%
embeddings, vocab, word_to_index, index_to_word, vocab_size = load_word_embeddings("embedding/word2vec.txt")

# %%
word_to_index["폰"]
# Out:
# 43

# %%
embeddings[43]
# Out:
# [-0.14557984,
#  0.016829247,
#  -0.6225956,
#  0.72838,
#  0.5608202,
#  -0.02858739,
#  0.11399057,
#  -0.07930925,
#  0.18284969,
#  0.19744067,
#  -0.22264831,
#  0.16054781,
#  -0.48303637,
#  0.32036388,
#  -0.07820362,
#  -0.24856932,
#  -0.12411274,
#  -0.8648818,
#  -0.051594675,
#  0.008955578,
#  -0.11973284,
#  -0.25558752,
#  -0.42160037,
#  0.13444282,
#  0.48941687,
#  -0.2961389,
#  0.2860343,
#  0.45653197,
#  0.28484613,
#  0.24604179,
#  -0.24901743,
#  -0.49485847,
#  0.32793656,
#  -0.15836336,
#  -0.41966224,
#  0.016247373,
#  -0.11009135,
#  0.5343439,
#  0.02720583,
#  -0.1367373,
#  0.3228519,
#  0.31499067,
#  -0.0997904,
#  -0.10375432,
#  0.3676059,
#  0.030807907,
#  -0.023195706,
#  -0.106393576,
#  -0.4339505,
#  0.121650614,
#  -0.06593861,
#  -0.20390928,
#  -0.28656945,
#  0.12025366,
#  0.078316174,
#  0.2890838,
#  0.21569826,
#  0.30545276,
#  -0.064022616,
#  -0.32919356,
#  0.3660378,
#  -0.07438021,
#  -0.13100073,
#  0.11181796,
#  0.39351696,
#  -0.13065901,
#  0.2815219,
#  -0.13879251,
#  0.10135274,
#  -0.38892677,
#  0.30976233,
#  -0.16091305,
#  0.049222738,
#  -0.2701184,
#  -0.1837117,
#  -0.2633058,
#  -0.049814522,
#  0.16501087,
#  0.3206694,
#  0.4074877,
#  -0.24851686,
#  0.8911057,
#  -0.30434802,
#  -0.026059119,
#  0.2251974,
#  0.32311967,
#  -0.28040448,
#  0.23104122,
#  -0.29598504,
#  0.40002486,
#  0.32816863,
#  -0.11953971,
#  -0.27587837,
#  -0.49158168,
#  0.021342335,
#  0.46246487,
#  0.47904444,
#  -0.49452338,
#  0.53118604,
#  0.59469503]

# %%
embeddings[word_to_index["폰"]]
# Out:
# [-0.14557984,
#  0.016829247,
#  -0.6225956,
#  0.72838,
#  0.5608202,
#  -0.02858739,
#  0.11399057,
#  -0.07930925,
#  0.18284969,
#  0.19744067,
#  -0.22264831,
#  0.16054781,
#  -0.48303637,
#  0.32036388,
#  -0.07820362,
#  -0.24856932,
#  -0.12411274,
#  -0.8648818,
#  -0.051594675,
#  0.008955578,
#  -0.11973284,
#  -0.25558752,
#  -0.42160037,
#  0.13444282,
#  0.48941687,
#  -0.2961389,
#  0.2860343,
#  0.45653197,
#  0.28484613,
#  0.24604179,
#  -0.24901743,
#  -0.49485847,
#  0.32793656,
#  -0.15836336,
#  -0.41966224,
#  0.016247373,
#  -0.11009135,
#  0.5343439,
#  0.02720583,
#  -0.1367373,
#  0.3228519,
#  0.31499067,
#  -0.0997904,
#  -0.10375432,
#  0.3676059,
#  0.030807907,
#  -0.023195706,
#  -0.106393576,
#  -0.4339505,
#  0.121650614,
#  -0.06593861,
#  -0.20390928,
#  -0.28656945,
#  0.12025366,
#  0.078316174,
#  0.2890838,
#  0.21569826,
#  0.30545276,
#  -0.064022616,
#  -0.32919356,
#  0.3660378,
#  -0.07438021,
#  -0.13100073,
#  0.11181796,
#  0.39351696,
#  -0.13065901,
#  0.2815219,
#  -0.13879251,
#  0.10135274,
#  -0.38892677,
#  0.30976233,
#  -0.16091305,
#  0.049222738,
#  -0.2701184,
#  -0.1837117,
#  -0.2633058,
#  -0.049814522,
#  0.16501087,
#  0.3206694,
#  0.4074877,
#  -0.24851686,
#  0.8911057,
#  -0.30434802,
#  -0.026059119,
#  0.2251974,
#  0.32311967,
#  -0.28040448,
#  0.23104122,
#  -0.29598504,
#  0.40002486,
#  0.32816863,
#  -0.11953971,
#  -0.27587837,
#  -0.49158168,
#  0.021342335,
#  0.46246487,
#  0.47904444,
#  -0.49452338,
#  0.53118604,
#  0.59469503]

# %% [markdown]
# ## 관심 기능 정의

# %%
# 스마트폰에 관련된 관심있는 기능들
functions = ["배터리", "촬영", "디자인", "화면", "OS", "색"]
function_size = len(functions)

# %% [markdown]
# ## 거리 행렬 구하기

# %%
import numpy as np
from scipy.spatial import distance

distance_matrix = np.zeros([function_size, vocab_size], dtype=np.float16) # 처음에 0핼렬로 정의
                                                                          # 크기는 6 (6가지 기능) x 23599

# %%
for func_idx, func in enumerate(functions):
    func_vec = embeddings[word_to_index[func]] 
    for word_idx, word_vec in enumerate(embeddings):
        distance_matrix[func_idx, word_idx] = distance.euclidean(func_vec, word_vec) #유클리디언 거리 구하기

# %% [markdown]
# ## 가중치 행렬 구하기

# %%
weight_matrix = np.zeros([function_size, vocab_size], dtype=np.float16)
for func_idx, per_func_distances in enumerate(distance_matrix):
    values = np.exp(-(per_func_distances ** 2) / 15)              # 정규화
    mean = np.mean(values)                                        # standard noarmal distribution으로 만듬 (0~1 사이의 수로 정규화)
    weight_matrix[func_idx, :] = values - mean + 0.5

# %% [markdown]
# ## 가중치 행렬 시각화

# %%
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.io import output_notebook, show

output_notebook()
def make_plot(title, hist, edges):
    p = figure(title=title, tools='', background_fill_color="#fafafa")
    p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
           fill_color="navy", line_color="white", alpha=0.5)
    p.y_range.start = 0
    p.grid.grid_line_color="white"
    return p
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
plots = []
for func_idx, func in enumerate(functions):
    hist, edges = np.histogram(weight_matrix[func_idx], density=True, bins=50)
    plots.append(make_plot(func, hist, edges))
show(gridplot(plots, ncols=2, plot_width=400, plot_height=300, toolbar_location=None))
# Out:
#   <div class="bk-root" id="2b1b65f4-2c97-4b67-83e4-c8467478906a" data-root-id="1212"></div>

# %%
battery_weights = [(token, score) for token, score in zip(vocab, weight_matrix[0])]

# %%
sorted(battery_weights, key=lambda x: x[1], reverse=True)
# Out:
# [('배터리', 1.057),
#  ('밧데리', 0.9307),
#  ('터리', 0.7607),
#  ('표준형', 0.748),
#  ('대용량', 0.705),
#  ('급속', 0.6855),
#  ('리튬', 0.6836),
#  ('충전기', 0.675),
#  ('슬림형', 0.673),
#  ('폴리머', 0.673),
#  ('대기전력', 0.666),
#  ('러닝', 0.666),
#  ('TTA', 0.666),
#  ('발열', 0.663),
#  ('오래간다', 0.659),
#  ('소모율', 0.6514),
#  ('상판', 0.6504),
#  ('간당간당', 0.6465),
#  ('암페어', 0.6455),
#  ('키트', 0.6455),
#  ('단다고', 0.6445),
#  ('변강', 0.6436),
#  ('가로길이', 0.6426),
#  ('mAH', 0.6416),
#  ('여분', 0.6396),
#  ('런타임', 0.6396),
#  ('하판', 0.6396),
#  ('커넥터', 0.6377),
#  ('넓이', 0.6377),
#  ('외장형', 0.6367),
#  ('비품', 0.6357),
#  ('타폰', 0.634),
#  ('DIY', 0.634),
#  ('나사', 0.633),
#  ('강쇠', 0.633),
#  ('배불뚝이', 0.632),
#  ('껍데기', 0.631),
#  ('기판', 0.628),
#  ('통했', 0.627),
#  ('RMAA', 0.627),
#  ('절벽', 0.627),
#  ('ap', 0.626),
#  ('뒤판', 0.626),
#  ('ISP', 0.626),
#  ('회로', 0.625),
#  ('오래간다고', 0.625),
#  ('거미줄', 0.625),
#  ('tta', 0.625),
#  ('풀로', 0.624),
#  ('애물단지', 0.624),
#  ('aux', 0.624),
#  ('라이트닝', 0.623),
#  ('교실', 0.623),
#  ('뽀대', 0.622),
#  ('항시', 0.622),
#  ('뒷부분', 0.621),
#  ('코랄', 0.621),
#  ('접점', 0.621),
#  ('도로는', 0.621),
#  ('EBH', 0.621),
#  ('극심', 0.62),
#  ('짹', 0.62),
#  ('본체', 0.619),
#  ('QC', 0.619),
#  ('타리', 0.619),
#  ('개조', 0.618),
#  ('엇비슷', 0.618),
#  ('쿨러', 0.618),
#  ('딸려온', 0.618),
#  ('접지', 0.618),
#  ('지랑', 0.617),
#  ('조퇴', 0.617),
#  ('중상', 0.617),
#  ('그중', 0.617),
#  ('통이', 0.616),
#  ('내장형', 0.616),
#  ('Ap', 0.616),
#  ('철한', 0.616),
#  ('주범', 0.616),
#  ('소비량', 0.616),
#  ('밀리암페어', 0.616),
#  ('사제', 0.615),
#  ('밧', 0.615),
#  ('옹이', 0.615),
#  ('rmaa', 0.615),
#  ('충전', 0.6143),
#  ('리시버', 0.6143),
#  ('서서히', 0.6143),
#  ('뒤쪽', 0.6143),
#  ('수신기', 0.6143),
#  ('부속품', 0.6143),
#  ('빨라집니다', 0.6143),
#  ('비교적', 0.6143),
#  ('전지', 0.6133),
#  ('따져도', 0.6133),
#  ('수화기', 0.6133),
#  ('커버도', 0.6133),
#  ('중가', 0.6123),
#  ('보조', 0.6113),
#  ('고속', 0.6113),
#  ('정확도', 0.6113),
#  ('느린데', 0.6113),
#  ('패킷', 0.6113),
#  ('멀다하고', 0.6113),
#  ('잔량', 0.6104),
#  ('기구', 0.6104),
#  ('걸려도', 0.6104),
#  ('뜨거워요', 0.6104),
#  ('진수', 0.6104),
#  ('hdd', 0.6104),
#  ('초고속', 0.6104),
#  ('전류', 0.6094),
#  ('아이피', 0.6094),
#  ('글씨체', 0.6094),
#  ('두깨', 0.6094),
#  ('안드로보이', 0.6094),
#  ('qi', 0.6094),
#  ('멈춥니다', 0.6094),
#  ('fhd', 0.6094),
#  ('악세', 0.6094),
#  ('늘어난다는', 0.6094),
#  ('정시', 0.6094),
#  ('완방', 0.6094),
#  ('부푸', 0.6094),
#  ('철사유', 0.6094),
#  ('악세서리', 0.6084),
#  ('소모품', 0.6084),
#  ('코일', 0.6084),
#  ('주변기기', 0.6084),
#  ('에너지', 0.6084),
#  ('블루스크린', 0.6084),
#  ('든든', 0.6084),
#  ('레이터', 0.6084),
#  ('니라', 0.6084),
#  ('사이클', 0.6084),
#  ('뜨거우', 0.6084),
#  ('mah', 0.6074),
#  ('임신', 0.6074),
#  ('기대치', 0.6074),
#  ('OIS', 0.6074),
#  ('만져서', 0.6074),
#  ('끌린다', 0.6074),
#  ('으다', 0.6074),
#  ('화재', 0.6074),
#  ('끼니', 0.6074),
#  ('변환기', 0.6074),
#  ('버텨요', 0.6074),
#  ('SAR', 0.6074),
#  ('SSD', 0.6064),
#  ('푸딩', 0.6064),
#  ('에이급', 0.6064),
#  ('질주', 0.6064),
#  ('DOCK', 0.6064),
#  ('스탠드', 0.6055),
#  ('허덕이', 0.6055),
#  ('핸들', 0.6055),
#  ('mh', 0.6055),
#  ('타제품', 0.6055),
#  ('갔으나', 0.6055),
#  ('KNOX', 0.6045),
#  ('연식', 0.6045),
#  ('게이지', 0.6045),
#  ('상성', 0.6045),
#  ('죽죽', 0.6045),
#  ('타기', 0.6045),
#  ('뜨거워집니다', 0.6045),
#  ('박대', 0.6045),
#  ('은박지', 0.6045),
#  ('통철', 0.6045),
#  ('거치대', 0.6035),
#  ('광속', 0.6035),
#  ('남아도', 0.6035),
#  ('임피던스', 0.6035),
#  ('정전기', 0.6035),
#  ('요걸로', 0.6035),
#  ('만듦새', 0.6035),
#  ('단번에', 0.6035),
#  ('기변가', 0.6035),
#  ('됏는데', 0.6035),
#  ('쓸래', 0.6035),
#  ('성장세', 0.6035),
#  ('health', 0.6035),
#  ('에어링크', 0.6035),
#  ('뜨거워지', 0.6025),
#  ('엘시디', 0.6025),
#  ('오링', 0.6025),
#  ('빠르기', 0.6025),
#  ('젠하이저', 0.6025),
#  ('ㅠㅠ갤럭시', 0.6025),
#  ('가품', 0.6025),
#  ('체력', 0.6025),
#  ('통실', 0.6025),
#  ('행사장', 0.6025),
#  ('왕조', 0.6025),
#  ('뜨거워졌', 0.6025),
#  ('게이밍', 0.6025),
#  ('이랜텍', 0.6016),
#  ('af', 0.6016),
#  ('수첩', 0.6016),
#  ('틀려요', 0.6016),
#  ('접착제', 0.6016),
#  ('늘어납니다', 0.6016),
#  ('근디', 0.6016),
#  ('심해졌', 0.6016),
#  ('쓰임새', 0.6016),
#  ('월산', 0.6016),
#  ('Siri', 0.6016),
#  ('턱없이', 0.6016),
#  ('거랑', 0.6016),
#  ('높였', 0.6016),
#  ('카바', 0.6016),
#  ('충천', 0.6016),
#  ('APU', 0.6016),
#  ('용두', 0.6016),
#  ('낍니다', 0.6016),
#  ('늘어남', 0.6016),
#  ('수요자', 0.6016),
#  ('지레', 0.6016),
#  ('찌그러진', 0.6016),
#  ('끼워도', 0.6006),
#  ('부쩍', 0.6006),
#  ('압축률', 0.6006),
#  ('mlt', 0.6006),
#  ('트랙패드', 0.6006),
#  ('교체기', 0.6006),
#  ('레베', 0.6006),
#  ('전력', 0.5996),
#  ('균열', 0.5996),
#  ('완벽히', 0.5996),
#  ('올케', 0.5996),
#  ('단다', 0.5996),
#  ('음음', 0.5996),
#  ('실증', 0.5996),
#  ('범주', 0.5996),
#  ('Lcd', 0.5996),
#  ('기니', 0.5996),
#  ('스티치', 0.5996),
#  ('판다면', 0.5996),
#  ('상부', 0.5996),
#  ('간다는데', 0.5996),
#  ('얼래', 0.5996),
#  ('악화', 0.5996),
#  ('속기', 0.5996),
#  ('벗긴', 0.5996),
#  ('칩과', 0.5996),
#  ('심해져', 0.5996),
#  ('현세대', 0.5996),
#  ('리소스', 0.5986),
#  ('뎀비', 0.5986),
#  ('빠져요', 0.5986),
#  ('앞판', 0.5986),
#  ('대사', 0.5986),
#  ('골드색', 0.5986),
#  ('반경', 0.5986),
#  ('중대', 0.5986),
#  ('이런가', 0.5986),
#  ('심박수', 0.5986),
#  ('고자라니', 0.5986),
#  ('우드', 0.5986),
#  ('수면', 0.5986),
#  ('레이어', 0.5986),
#  ('Mp', 0.5986),
#  ('과대광고', 0.5986),
#  ('대여섯', 0.5986),
#  ('Qi', 0.5986),
#  ('급속히', 0.5986),
#  ('아톰', 0.5977),
#  ('땡긴다', 0.5977),
#  ('뜨끈뜨끈', 0.5977),
#  ('마개', 0.5977),
#  ('Ips', 0.5977),
#  ('재고량', 0.5977),
#  ('노멀', 0.5977),
#  ('LL', 0.5977),
#  ('미락', 0.5977),
#  ('후처리', 0.5977),
#  ('된다니까', 0.5977),
#  ('악조건', 0.5977),
#  ('방향키', 0.5977),
#  ('망설여집니다', 0.5977),
#  ('됫죠', 0.5977),
#  ('HT', 0.5977),
#  ('함꼐', 0.5977),
#  ('Zoom', 0.5977),
#  ('Anker', 0.5977),
#  ('헬스', 0.5967),
#  ('저항', 0.5967),
#  ('선택지', 0.5967),
#  ('ram', 0.5967),
#  ('덮개', 0.5967),
#  ('오락가락', 0.5967),
#  ('밑부분', 0.5967),
#  ('광역시', 0.5967),
#  ('통짜', 0.5967),
#  ('쩜', 0.5967),
#  ('괜찬은데', 0.5967),
#  ('뺴고', 0.5967),
#  ('적수', 0.5967),
#  ('보네', 0.5967),
#  ('살돈', 0.5967),
#  ('브리핑', 0.5967),
#  ('뭐니뭐니', 0.5967),
#  ('특이점', 0.5967),
#  ('그래미', 0.5967),
#  ('잡혀야', 0.5967),
#  ('세나', 0.5967),
#  ('빠를지', 0.5967),
#  ('자석', 0.5957),
#  ('이온', 0.5957),
#  ('인내', 0.5957),
#  ('터치패드', 0.5957),
#  ('심함', 0.5957),
#  ('부식', 0.5957),
#  ('부속', 0.5957),
#  ('돕니다', 0.5957),
#  ('자켓', 0.5957),
#  ('빠른가', 0.5957),
#  ('그리도', 0.5957),
#  ('리가', 0.5957),
#  ('전산망', 0.5957),
#  ('오른손잡이', 0.5957),
#  ('랜턴', 0.5957),
#  ('껍질', 0.5957),
#  ('암말', 0.5957),
#  ('글로나스', 0.5957),
#  ('PDP', 0.5957),
#  ('버금', 0.5957),
#  ('잠금장치', 0.5957),
#  ('찌꺼기', 0.5957),
#  ('심한지', 0.5957),
#  ('느릿느릿', 0.5957),
#  ('걸친', 0.5957),
#  ('치고는', 0.5957),
#  ('꾸졌', 0.5957),
#  ('녹아내리', 0.5957),
#  ('딸렸', 0.5957),
#  ('TEGRA', 0.5957),
#  ('군사', 0.5957),
#  ('인방', 0.5957),
#  ('동속', 0.5957),
#  ('포장지', 0.5957),
#  ('미세먼지', 0.5957),
#  ('딸아이', 0.5947),
#  ('액세서리', 0.5947),
#  ('에보', 0.5947),
#  ('앞선', 0.5947),
#  ('갈기', 0.5947),
#  ('한달', 0.5947),
#  ('몽블랑', 0.5947),
#  ('dhd', 0.5947),
#  ('개량', 0.5947),
#  ('싸인', 0.5947),
#  ('겹쳐', 0.5947),
#  ('마이크로', 0.5947),
#  ('빠뜨렸', 0.5947),
#  ('빨라도', 0.5947),
#  ('gpro', 0.5947),
#  ('딴건', 0.5947),
#  ('금세', 0.5947),
#  ('뻑나', 0.5947),
#  ('실금', 0.5947),
#  ('IO', 0.5947),
#  ('경도', 0.5947),
#  ('철판', 0.5947),
#  ('해본다고', 0.5947),
#  ('화시', 0.5947),
#  ('더불어', 0.5947),
#  ('진작에', 0.5947),
#  ('ㅇㅁㅇ', 0.5947),
#  ('두꺼운데', 0.5947),
#  ('섭취', 0.5947),
#  ('배분', 0.5947),
#  ('튀어나옵니다', 0.5947),
#  ('탈라', 0.5947),
#  ('mha', 0.5947),
#  ('gh', 0.5947),
#  ('유닛', 0.5938),
#  ('거슬렸', 0.5938),
#  ('그래서인지', 0.5938),
#  ('가구', 0.5938),
#  ('패션', 0.5938),
#  ('평면', 0.5938),
#  ('철할', 0.5938),
#  ('★★★★★', 0.5938),
#  ('심해져서', 0.5938),
#  ('합체', 0.5938),
#  ('구구', 0.5938),
#  ('소가죽', 0.5938),
#  ('검둥이', 0.5938),
#  ('교통비', 0.5938),
#  ('복제', 0.5938),
#  ('다중작업', 0.5938),
#  ('스콜', 0.5938),
#  ('페화', 0.5938),
#  ('걸린다', 0.593),
#  ('늘려서', 0.593),
#  ('느려도', 0.593),
#  ('바꿔왔', 0.593),
#  ('투용', 0.593),
#  ('프라이드', 0.593),
#  ('오름', 0.593),
#  ('고라도', 0.593),
#  ('단다는', 0.593),
#  ('뺴면', 0.593),
#  ('할애비', 0.593),
#  ('패망', 0.593),
#  ('비주류', 0.593),
#  ('제원', 0.593),
#  ('추우', 0.593),
#  ('끌어안', 0.593),
#  ('봉실', 0.593),
#  ('초정', 0.593),
#  ('얄쌍', 0.593),
#  ('재료비', 0.593),
#  ('케라', 0.593),
#  ('순정과', 0.593),
#  ('에쿠스', 0.593),
#  ('넷플릭스', 0.593),
#  ('줄때', 0.593),
#  ('빨라져서', 0.593),
#  ('종전', 0.593),
#  ('무거운데', 0.593),
#  ('용이성', 0.593),
#  ('빨라진다', 0.593),
#  ('오금', 0.593),
#  ('무개', 0.593),
#  ('번지르르', 0.593),
#  ('Kg', 0.593),
#  ('문제기', 0.593),
#  ('Fhd', 0.593),
#  ('CMOS', 0.593),
#  ('미닫이', 0.593),
#  ('누크', 0.592),
#  ('지피에스', 0.592),
#  ('요것', 0.592),
#  ('렘', 0.592),
#  ('HDD', 0.592),
#  ('게임패드', 0.592),
#  ('카본', 0.592),
#  ('오차', 0.592),
#  ('초저', 0.592),
#  ('청색', 0.592),
#  ('요란', 0.592),
#  ('으아아', 0.592),
#  ('내버려', 0.592),
#  ('사탕', 0.592),
#  ('흘렀', 0.592),
#  ('견주', 0.592),
#  ('삐걱', 0.592),
#  ('당겨', 0.592),
#  ('실측', 0.592),
#  ('두려움', 0.592),
#  ('적다', 0.592),
#  ('아웃도어', 0.592),
#  ('강탈', 0.592),
#  ('살펴봐도', 0.592),
#  ('쑥쑥', 0.592),
#  ('교류', 0.592),
#  ('르그랑', 0.592),
#  ('굴곡진', 0.592),
#  ('해상력', 0.592),
#  ('BAT', 0.592),
#  ('부러져서', 0.592),
#  ('TAG', 0.592),
#  ('다닐까', 0.592),
#  ('발열량', 0.592),
#  ('수중', 0.592),
#  ('난제', 0.592),
#  ('SAMOLED', 0.592),
#  ('외전', 0.592),
#  ('베', 0.591),
#  ('GG', 0.591),
#  ('희', 0.591),
#  ('파나소닉', 0.591),
#  ('겉보기', 0.591),
#  ('대동소이', 0.591),
#  ('과소비', 0.591),
#  ('들뜸', 0.591),
#  ('예비군', 0.591),
#  ('번외', 0.591),
#  ('글로', 0.591),
#  ('떔에', 0.591),
#  ('생김새', 0.591),
#  ('제방', 0.591),
#  ('봉지', 0.591),
#  ('광고비', 0.591),
#  ('소나', 0.591),
#  ('발랐', 0.591),
#  ('들쭉날쭉', 0.591),
#  ('끕니다', 0.591),
#  ('는데두', 0.591),
#  ('잠잘', 0.591),
#  ('실체', 0.591),
#  ('정감', 0.591),
#  ('드리프트', 0.591),
#  ('정내', 0.591),
#  ('블랙마켓', 0.591),
#  ('신차', 0.591),
#  ('손잡이', 0.591),
#  ('괜찬아요', 0.591),
#  ('벌어짐', 0.591),
#  ('가벼웠', 0.591),
#  ('kT', 0.591),
#  ('스코어', 0.591),
#  ('오릅니다', 0.591),
#  ('막무가내', 0.591),
#  ('이뤄지는', 0.591),
#  ('가르', 0.591),
#  ('몸체', 0.591),
#  ('출중', 0.591),
#  ('RF', 0.591),
#  ('부상', 0.591),
#  ('방습', 0.591),
#  ('면도', 0.591),
#  ('셀러론', 0.591),
#  ('드이', 0.591),
#  ('첫마디', 0.591),
#  ('ㅠ갤', 0.591),
#  ('고어텍스', 0.591),
#  ('집적도', 0.591),
#  ('부록', 0.591),
#  ('그만뒀', 0.591),
#  ('순간순간', 0.591),
#  ('재쳐', 0.591),
#  ('Knox', 0.591),
#  ('산후', 0.591),
#  ('미사', 0.591),
#  ('DNLA', 0.591),
#  ('엉덩이', 0.59),
#  ('솔까말', 0.59),
#  ('강압', 0.59),
#  ('끌림', 0.59),
#  ('이별', 0.59),
#  ('브레이크', 0.59),
#  ('챗온', 0.59),
#  ('과부하', 0.59),
#  ('도라', 0.59),
#  ('볼거리', 0.59),
#  ('나을까', 0.59),
#  ('일곱', 0.59),
#  ('펩시', 0.59),
#  ('암담', 0.59),
#  ('선자', 0.59),
#  ('거슬러', 0.59),
#  ('톡톡이', 0.59),
#  ('내구력', 0.59),
#  ('치티', 0.59),
#  ('상체', 0.59),
#  ('배부름', 0.59),
#  ('교환기', 0.59),
#  ('워너비', 0.59),
#  ('JDI', 0.59),
#  ('쓸데없이', 0.589),
#  ('형편없', 0.589),
#  ('부푼', 0.589),
#  ('아쉬워서', 0.589),
#  ('시거', 0.589),
#  ('소모전', 0.589),
#  ('바이러스', 0.589),
#  ('단선', 0.589),
#  ('큐브릭', 0.589),
#  ('펜티엄', 0.589),
#  ('팟캐스트', 0.589),
#  ('스케일', 0.589),
#  ('음색', 0.589),
#  ('카메라폰', 0.589),
#  ('누래지', 0.589),
#  ('바닷물', 0.589),
#  ('떨어졌었', 0.589),
#  ('TSMC', 0.589),
#  ('아껴서', 0.589),
#  ('걸릴지', 0.589),
#  ('휠씬', 0.589),
#  ('제것은', 0.589),
#  ('성질나', 0.589),
#  ('페블블루는', 0.589),
#  ('자다', 0.589),
#  ('ㅠㅠ빨리', 0.589),
#  ('버린지', 0.589),
#  ('금이', 0.589),
#  ('전년', 0.589),
#  ('인화', 0.589),
#  ('대두', 0.589),
#  ('고른다면', 0.589),
#  ('악어', 0.589),
#  ('못쓴다고', 0.589),
#  ('빠진다', 0.589),
#  ('졌으나', 0.589),
#  ('pin', 0.589),
#  ('삼각대', 0.589),
#  ('심해도', 0.589),
#  ('넘쳐서', 0.589),
#  ('실루엣', 0.589),
#  ('걸레', 0.589),
#  ('크러쉬', 0.589),
#  ('유막', 0.589),
#  ('간소', 0.589),
#  ('사명', 0.589),
#  ('변강쇠가', 0.589),
#  ('딸깍거리', 0.589),
#  ('LET', 0.589),
#  ('생겼으니', 0.589),
#  ('벗길', 0.589),
#  ('헐거워', 0.589),
#  ('투발', 0.589),
#  ('TC', 0.589),
#  ('까져', 0.589),
#  ('껴져', 0.589),
#  ('MF', 0.589),
#  ('파인데', 0.589),
#  ('불식', 0.589),
#  ('빳데리', 0.589),
#  ('데스크톱', 0.589),
#  ('뛰어남', 0.589),
#  ('병목', 0.589),
#  ('꼬리표', 0.589),
#  ('했었으나', 0.589),
#  ('iface', 0.589),
#  ('EXT', 0.589),
#  ('너비', 0.589),
#  ('휑', 0.589),
#  ('재료', 0.588),
#  ('매칭', 0.588),
#  ('써봐도', 0.588),
#  ('리스크', 0.588),
#  ('틈새', 0.588),
#  ('닌텐도', 0.588),
#  ('썼으니', 0.588),
#  ('광각', 0.588),
#  ('이러면', 0.588),
#  ('DPI', 0.588),
#  ('나무랄', 0.588),
#  ('실속', 0.588),
#  ('콘센트', 0.588),
#  ('이부재', 0.588),
#  ('자유도', 0.588),
#  ('오래간다는', 0.588),
#  ('근근히', 0.588),
#  ('전화비', 0.588),
#  ('디코더', 0.588),
#  ('넘칩니다', 0.588),
#  ('재림', 0.588),
#  ('다투', 0.588),
#  ('한계점', 0.588),
#  ('그른가', 0.588),
#  ('됐으며', 0.588),
#  ('데크', 0.588),
#  ('올라온다', 0.588),
#  ('비일비재', 0.588),
#  ('흉기', 0.588),
#  ('딸린다', 0.588),
#  ('그러저럭', 0.588),
#  ('철개', 0.588),
#  ('콘크리트', 0.588),
#  ('인색', 0.588),
#  ('혼용', 0.588),
#  ('끝난지', 0.588),
#  ('저음부', 0.588),
#  ('불량증', 0.588),
#  ('벗겨야', 0.588),
#  ('했었으니', 0.588),
#  ('댄다고', 0.588),
#  ('경이롭', 0.588),
#  ('가설', 0.588),
#  ('LRMG', 0.588),
#  ('하이패스', 0.588),
#  ('요놈', 0.587),
#  ('부피', 0.587),
#  ('샌디스크', 0.587),
#  ('아우라', 0.587),
#  ('한물', 0.587),
#  ('페블이', 0.587),
#  ('추이', 0.587),
#  ('만능', 0.587),
#  ('증발', 0.587),
#  ('뺴고는', 0.587),
#  ('불문', 0.587),
#  ('무거움', 0.587),
#  ('괜찬네요', 0.587),
#  ('본지', 0.587),
#  ('벡', 0.587),
#  ('스케줄', 0.587),
#  ('두드러지', 0.587),
#  ('소켓', 0.587),
#  ('apu', 0.587),
#  ('CAT', 0.587),
#  ('넘보', 0.587),
#  ('사진기', 0.587),
#  ('뚝딱', 0.587),
#  ('놀러갔', 0.587),
#  ('센치', 0.587),
#  ('치워', 0.587),
#  ('엄청납니다', 0.587),
#  ('요센', 0.587),
#  ('Ios', 0.587),
#  ('데미지', 0.587),
#  ('탭스', 0.587),
#  ('꿀꺽', 0.587),
#  ('할라구요', 0.587),
#  ('착용감', 0.587),
#  ('커보였', 0.587),
#  ('식인', 0.587),
#  ('피사체', 0.587),
#  ('하나같이', 0.587),
#  ('체급', 0.587),
#  ('트러블', 0.587),
#  ('통채', 0.587),
#  ('전방', 0.587),
#  ('어쨌건', 0.587),
#  ('참사', 0.587),
#  ('버텨서', 0.587),
#  ('된다던가', 0.587),
#  ('얼레', 0.587),
#  ('합쳐져서', 0.587),
#  ('이클립스', 0.587),
#  ('짜잔', 0.587),
#  ('빌어먹을', 0.587),
#  ('수수', 0.587),
#  ('분배', 0.587),
#  ('둔다고', 0.587),
#  ('갈구', 0.587),
#  ('목돈', 0.587),
#  ('직사각형', 0.587),
#  ('부셔지', 0.587),
#  ('둬도', 0.587),
#  ('속마음', 0.587),
#  ('반기', 0.587),
#  ('노화', 0.587),
#  ('징검다리', 0.587),
#  ('건전지', 0.587),
#  ('벗겨져', 0.587),
#  ('으냐', 0.587),
#  ('오보', 0.587),
#  ('열외', 0.587),
#  ('구리구리', 0.587),
#  ('까짓', 0.587),
#  ('덜덜이', 0.587),
#  ('킬로', 0.587),
#  ('갠데', 0.587),
#  ('어선지', 0.587),
#  ('따라간다면', 0.587),
#  ('제트오디오', 0.587),
#  ('손목시계', 0.587),
#  ('강성', 0.587),
#  ('HML', 0.587),
#  ('gx', 0.587),
#  ('MADE', 0.587),
#  ('퀄콤', 0.587),
#  ('밑장', 0.587),
#  ('쩨', 0.587),
#  ('금오', 0.587),
#  ('제조자', 0.587),
#  ('내준다면', 0.587),
#  ('철철', 0.587),
#  ('떠안', 0.587),
#  ('됩니다요', 0.587),
#  ('열세', 0.587),
#  ('명도', 0.587),
#  ('에어포트', 0.587),
#  ('여름철', 0.587),
#  ('PTV', 0.587),
#  ('가출', 0.586),
#  ('줄줄', 0.586),
#  ('탈탈', 0.586),
#  ('도시바', 0.586),
#  ('사니', 0.586),
#  ('홀더', 0.586),
#  ('질린다', 0.586),
#  ('신기종', 0.586),
#  ('족히', 0.586),
#  ('금번', 0.586),
#  ('Ram', 0.586),
#  ('나이키', 0.586),
#  ('고인', 0.586),
#  ('여덟', 0.586),
#  ('아낄', 0.586),
#  ('신제품', 0.586),
#  ('와서야', 0.586),
#  ('페블블루에', 0.586),
#  ('요즈음', 0.586),
#  ('두표', 0.586),
#  ('qr', 0.586),
#  ('반올림', 0.586),
#  ('뒤엎', 0.586),
#  ('NOTE', 0.586),
#  ('WIMAX', 0.586),
#  ('Orz', 0.586),
#  ('질림', 0.586),
#  ('막대기', 0.586),
#  ('찍혀요', 0.586),
#  ('고민거리', 0.586),
#  ('avplayer', 0.586),
#  ('별매', 0.586),
#  ('제아무리', 0.586),
#  ('ht', 0.586),
#  ('외상', 0.586),
#  ('미적지근', 0.586),
#  ('날아간', 0.586),
#  ('춘추', 0.586),
#  ('스중', 0.586),
#  ('연배', 0.586),
#  ('웟', 0.586),
#  ('lteA', 0.586),
#  ('튕김이', 0.586),
#  ('커진다면', 0.586),
#  ('점박이', 0.586),
#  ('기정', 0.586),
#  ('체면', 0.586),
#  ('순백색', 0.586),
#  ('뺀다고', 0.586),
#  ('세이버', 0.586),
#  ('탈탈탈', 0.586),
#  ('젠더', 0.585),
#  ('문제지', 0.585),
#  ('놑', 0.585),
#  ('자바', 0.585),
#  ('세로줄', 0.585),
#  ('Micro', 0.585),
#  ('별말', 0.585),
#  ('떙기네요', 0.585),
#  ('먹였', 0.585),
#  ('최곤데', 0.585),
#  ('글꼴', 0.585),
#  ('다다익선', 0.585),
#  ('아쉬우', 0.585),
#  ('쬐', 0.585),
#  ('가계부', 0.585),
#  ('웹캠', 0.585),
#  ('지베', 0.585),
#  ('JIG', 0.585),
#  ('정사각형', 0.585),
#  ('그랜저', 0.585),
#  ('시원찮', 0.585),
#  ('발렌티누스', 0.585),
#  ('넙대', 0.585),
#  ('초스피드', 0.585),
#  ('챙겨야', 0.585),
#  ('아포', 0.585),
#  ('삐걱삐걱', 0.585),
#  ('후려쳐서', 0.585),
#  ('노트라', 0.585),
#  ('심도', 0.585),
#  ('그럴만한', 0.585),
#  ('맘놓', 0.585),
#  ('번화가', 0.585),
#  ('이동성', 0.585),
#  ('tn', 0.585),
#  ('빠졌었', 0.585),
#  ('자수', 0.585),
#  ('입출력', 0.585),
#  ('병목현상', 0.585),
#  ('선망', 0.585),
#  ('글케', 0.585),
#  ('울궈먹', 0.585),
#  ('인트', 0.585),
#  ('아닐지라도', 0.585),
#  ('클로버', 0.585),
#  ('맞붙', 0.585),
#  ('원활히', 0.585),
#  ('코아', 0.585),
#  ('똥물', 0.585),
#  ('진절머리', 0.585),
#  ('한껏', 0.585),
#  ('턱주가리', 0.585),
#  ('미끄러워서', 0.585),
#  ('qc', 0.585),
#  ('달품', 0.585),
#  ('ㅜㅜ갤럭시', 0.585),
#  ('아름다웠', 0.585),
#  ('너끈히', 0.585),
#  ('샀으나', 0.585),
#  ('케나', 0.585),
#  ('빨르', 0.585),
#  ('숙모', 0.585),
#  ('소보', 0.585),
#  ('짜임새', 0.585),
#  ('발림', 0.585),
#  ('하마터면', 0.585),
#  ('약했', 0.585),
#  ('패대기쳤', 0.585),
#  ('보여준다면', 0.585),
#  ('소모량', 0.584),
#  ('가급적', 0.584),
#  ('새것', 0.584),
#  ('하난', 0.584),
#  ('변종', 0.584),
#  ('가장자리', 0.584),
#  ('급격', 0.584),
#  ('쵝오', 0.584),
#  ('급감', 0.584),
#  ('바이바이', 0.584),
#  ('탄지', 0.584),
#  ('바꾼다', 0.584),
#  ('걸쳐서', 0.584),
#  ('이염', 0.584),
#  ('부러질', 0.584),
#  ('siri', 0.584),
#  ('GPRS', 0.584),
#  ('다를까요', 0.584),
#  ('낡', 0.584),
#  ('구혜선', 0.584),
#  ('스틸', 0.584),
#  ('보지', 0.584),
#  ('날씬', 0.584),
#  ('케익', 0.584),
#  ('나빠진', 0.584),
#  ('만만찮', 0.584),
#  ('간간이', 0.584),
#  ('어림', 0.584),
#  ('이어진', 0.584),
#  ('특입니다', 0.584),
#  ('되도록', 0.584),
#  ('해답', 0.584),
#  ('테크라', 0.584),
#  ('무수히', 0.584),
#  ('스핑크', 0.584),
#  ('이하라', 0.584),
#  ('달라져서', 0.584),
#  ('오렌지색', 0.584),
#  ('천지개벽', 0.584),
#  ('덤핑', 0.584),
#  ('이렌', 0.584),
#  ('맛본', 0.584),
#  ('괜찬은거', 0.584),
#  ('테리', 0.584),
#  ('비견', 0.584),
#  ('버렸으니', 0.584),
#  ('희생양', 0.584),
#  ('SDXC', 0.584),
#  ('차인', 0.584),
#  ('한족', 0.584),
#  ('천연', 0.584),
#  ('다다닥', 0.584),
#  ('제제', 0.584),
#  ('ㅠㅠ왜', 0.584),
#  ('번뇌', 0.584),
#  ('제껴', 0.584),
#  ('증대', 0.584),
#  ('va', 0.584),
#  ('반사광', 0.584),
#  ('Ex', 0.584),
#  ('어떠셨', 0.584),
#  ('에클레어', 0.584),
#  ('금형', 0.584),
#  ('정보량', 0.584),
#  ('최단', 0.584),
#  ('설계도', 0.584),
#  ('적색', 0.584),
#  ('해파리', 0.584),
#  ('고르기', 0.584),
#  ('철안', 0.584),
#  ('요베', 0.584),
#  ('PTP', 0.584),
#  ('휘어짐', 0.584),
#  ('중국산', 0.584),
#  ('미관상', 0.584),
#  ('까졌', 0.584),
#  ('amh', 0.584),
#  ('배불러요', 0.584),
#  ('데스트', 0.584),
#  ('친정', 0.584),
#  ('트레이서', 0.584),
#  ('된다지만', 0.584),
#  ('열댓', 0.584),
#  ('매스티지', 0.584),
#  ('직찍', 0.584),
#  ('고음부', 0.584),
#  ('말끔히', 0.584),
#  ('훔쳐간', 0.584),
#  ('케이스', 0.583),
#  ('애착', 0.583),
#  ('원색', 0.583),
#  ('모자란', 0.583),
#  ('기본기', 0.583),
#  ('돼도', 0.583),
#  ('SE', 0.583),
#  ('나선', 0.583),
#  ('가벼움', 0.583),
#  ('대나', 0.583),
#  ('터치스크린', 0.583),
#  ('리어', 0.583),
#  ('로그', 0.583),
#  ('PSP', 0.583),
#  ('기왕이면', 0.583),
#  ('eq', 0.583),
#  ('파츠', 0.583),
#  ('Dmb', 0.583),
#  ('감이', 0.583),
#  ('퀘스트', 0.583),
#  ('긱', 0.583),
#  ('건드린', 0.583),
#  ('자연스레', 0.583),
#  ('경색', 0.583),
#  ('난생', 0.583),
#  ('일으킨', 0.583),
#  ('진거', 0.583),
#  ('유의미', 0.583),
#  ('정격', 0.583),
#  ('콘서트', 0.583),
#  ('흥했', 0.583),
#  ...]

# %% [markdown]
# ## Document-Term Matrix 구축

# %%
corpus = open("data/phone_review_mecab.txt", "r", encoding="utf-8").readlines()
corpus = list(set([el.strip() for el in corpus if len(el.split()) < 31]))

# %%
import random
corpus = random.sample(corpus, 3000)

# %%
corpus
# Out:
# ['디자인 이 궁금 해요 ＊',
#  '용도 에 따라 구매 를 하 셔야 할 듯 갤 s 가 훨씬 좋 은 부분 도 있 으니까요',
#  '옵티머스 LTE 2 판매량 7 0 만 대 돌파',
#  '옵 쥐 가 제일 상급 ips 입니다 아이폰 도 lg 디 플 에서 공급 받 는 거 쓰 지만 옵 g 보단 한 단계 낮 은 ips 이 구요',
#  '겔 스 플레시 없 어요 헐',
#  '그러 쿤 요 ㅠㅠ 에 구',
#  '한 7 번 본 듯',
#  '아래쪽 은 갤 스 때 도 그랬 어요 볼록 한 곳 에 안테나 들어가 있 는 곳',
#  '검 게 보여서 필터 적용 한 느낌 이 들 나서 요',
#  '국내 분 들 이 커널 만 개발 해 주 시 면 괜찮 다 능',
#  '변경 하 고 받 는 것 도 가능 합니다 쿠폰 받 는 시점 에 갤 3 갤럭시 요금제 면 바로 가능 합니다',
#  '하긴 지금 삼성 애플 두 기업 의 네임 밸류 가 지나치 게 높 다 보 니 시장 이 양극 화 되 는 문제 도 있 죠 ㅋㅋ',
#  '며칠 전 에 뽐 게에 올라온 4 6 0 원 짤 인가 여섯 장 질렀 는데 괜찮 네요',
#  '추진력 굳',
#  '말 끝 나 니 바로 눈 ㅎㅎㅎ 5 1 2',
#  '아드 레노 는 이번 스냅 4 세대 프로 서 제대로 뒤집 기 성공 했 죠 스냅 4 세대 땐 쓸 만하다 였 고요',
#  '진짜 네임 드 님 출현 ㅎㅎ ㅊㅊ',
#  '삼성 은 아직 멀 었 네여 ㅉㅉ',
#  '판매자 도 정책 이 우찌 될지 는 모르 는 거 니까요',
#  '테티 이 가 낫 지 않 나요 베레 2 면 몰라도 베레기 는 ㅋㅋ',
#  '아 그렇 군요 LTE 로 한번 찾 아 봐야 겠 네요',
#  '쿼드 코 어시장 에서 는 갤럭시 s 3 vs HTC One X 의 싸움 이 겠 군요',
#  'Thanks',
#  '지금 시점 에 저건 너무 비싸 네요',
#  'LGU 갤럭시 노트 1 6 G 4 1 0 0 0 0 원 떴 네요 최저 가 경신',
#  '떳 네요 달렸 어요 ㅋㅋ 친구 꺼',
#  '뽐뿌 는 실시간 이 군요 ㅋㅋ',
#  '옵티머스 LTE 2 배터리 나눔 합니다',
#  '프라다 st 쪽 은 검 은 색 이 괜찮 은 거 같 아요 ㅋㅋ ㅋㅋ',
#  '3 G 문제 이 니 중계기 겠 죠 ㅎ',
#  '그냥 무난 하 기 는 한데 요즘 따라 마음 에 안 차 기 는 해요 ㅎㅎ',
#  '야누스 같 은 경우 두 개 로 분할 됬 던 걸로 기억 합니다',
#  '폰 부서져서 헬 지 폰 첨 써 봣는데 다신 안 씁니다',
#  '작업 관리자 구글 그놈',
#  '그냥 2 4 개월 1 5 만 원 신규 정책 추가 된다는 소리 같 네요',
#  '이 로써 헬 지 는 \\ 역사 는 반복 된다 \\',
#  '감사 합니다 지금 마음 같 아선 딱 한 번 만 더 교 품 받 을 생각 인데 그 마저 도 양품 이 아니 면 진상 될까 봐서 요 ㅠ',
#  '님 만 그런 듯',
#  'ㅋ 시 뤼 우스 1 2 1 2 ㅋㅋ 과연',
#  'ngel 님 자기 검열 ㅋ 이것 과 의미 가 같 은 겁니다',
#  '고생 이 많 으시 네요 위 추 드립니다',
#  '오늘 0 9 0 0 땡 출근 했 네요 버스 왜 이리 더디 게 다니 나요',
#  '와 대박 시리우스 선착순 1 대 인 거 제 가 탔 네요',
#  '제말이 제돈내고 산다는 데 물건 이 없 다는 말 도 안 되 는 소리 나 해 샀 고 ㅜㅜㅜㅜ',
#  '고장난 것 에 유심 인식 이 안 됩니다 ㅠ',
#  '시리우스 터치 말 만아 도 그게 1 2 개월 로 풀리 면 얘기 는 달라지 죠 ㅋ',
#  '아임 백 ＊',
#  '4 5 에 추가 금 없이 나온 적 이 있 나요 저 도 베 가 기다리 고 있 습니다',
#  '저 도 갤 s 지겨워 져서 팔 고 다른 걸로 넘어갈까 생각 중 인데 혹시 갤 s 할 부 남 은 거 기기 팔 아서 매 꾸 셨 나요',
#  '갤럭시 S 3 핑크 출시 예정 jpg',
#  '저건 해상도 가 아니 라 칼라 아닌가요 from CLiOS',
#  '갤럭시 s 3 요즘 엄청 저렴 해졌 네요',
#  '삼성 갤럭시 A 8 골드',
#  'as 대박 ㅋ 가개 통 급 이 네요 악 게사리 빼 고',
#  '스카이 의 숨겨진 스펙 입니다',
#  '점유 율 도 그렇 고 업체 들 실적 도 있 으니 아무래도 연말 에 많이 풀리 겠 죠',
#  '옵티머스 LTE 2 wifi 연결 해결책',
#  '통메',
#  '진심 입니다',
#  '해상도 가 조금 아쉽 군요 다 좋 은데',
#  '아이패드 가 있 다면 안드로이드 를 써 보 는 것 도 재밌 죠',
#  '갤 투 쓰리 쥐 사용 자 는 안 대 는 건가 ㅜㅜ',
#  '네 알 면 더 가슴 이 아플 것 같 네요 ㅎ',
#  'ㅎㅎ 오죽 하 면 아이폰 만 쓰 겠 다던 와이프 가 갤 삼 바꿔 달 란 소리 를 할까요 ㅋ',
#  '모든 안드로이드 기기 가 화면 비율 이 젤 높 지 않 나요 ㅎ',
#  'ㅋㅋ 과연',
#  '제 동생 과 아버지 께서 베가 레이서 1 사용 합니다 음 어떤 댓글 을 달 아야 할지 모르 겠 군요 ㄷ ㄷ',
#  '화면 큰 갤럭시 S 2 면 최고 죠 지금 ㅋㅋ',
#  '전 또 졸러 갑니다 즐거운 저녁 되 세요',
#  '나와라 베가 베 가 ㅋㅋㅋ',
#  '괜찮 은 거 같 은데 아 4 가 도입 보류 니 고려 해봐야 겠 다 골드 브라운 색상 굿',
#  '이보 와 같 네요',
#  '옵티머스 3 d 큐브 3 d 프로젝터 조합 에 대한 생각',
#  '전 루팅 해서 지워 씁니다 그래도 이 정도 는 설정 으로 선택 가능 하 게 하 면 좋 을 텐데 참 a',
#  '전 자연산 회 먹 었 지용 ㅋ',
#  '프로 요 1 0 월 로 미뤄졌 네요 ㅡㅡㅋ',
#  '변한 지 가 꾀 됐 죠 ㅜㅜㅋ',
#  '갤럭시 S 3 전 용 자전거 거치대 는 아직 안 나왔 겠죠',
#  '노트 1 은 젤리빈 이 나 을 텐데요 ＊',
#  'shawnlee 님 dslr 을 항시 휴대 하 시 나요',
#  '베가 LTE vs 레이더 어느 쪽 손 을 들 어 주 시 겠 어요',
#  '잠금 화면 에 부재중 전화 랑 sms 카운트 해 주 는 건 어떤 건가요 카톡 도 되 나요',
#  '여기 이름 이 많이 보이 는 것 같 은데 이곳 이 싼 가요 주소 가 어떻게 되 나요',
#  '갤럭시 s 3 이번 에 는 s 2 때 처럼 스팟 이 없 나요',
#  '엘 라고 구멍 사이 에 때 가 끼 지 않 나요',
#  '광고 호란 목소리 딱 입니다 from CV',
#  '3 3 개월 쓴 베가 레이서 1 안 녀 엉 ㅠㅠ 화이트골드 이 뿌 던데 아쉽',
#  '옵 두 배 가 좋 을 듯',
#  '조 콤 쓰 다 보 면 가끔 누르 는 감 이 잇 기 는 한대요 왼 만 해서 는 감압 식 이 라는 거 못 느낍니다',
#  '이게 말 인지 방구 인지 카피 만세',
#  '4 s 사용 하 는 데 불편 함 어느 정도 인가요',
#  '회선 후 덜 덜 이 시 네요 ㅋ',
#  '아웃 포 커싱 도 되 고 완전 좋 아요',
#  '피눈물 이 콸콸 콸',
#  '출고가 2 백 찍 을지 도 ㅋ',
#  '거래 안 할꺼 면 죄송 하 다고 취소 한다고 문자 라고 하나 보내 주 지 참',
#  '이렇게 퍼 오 는 건 불 펌 으로 신고 당할 수 있 어요 기사 는 주소 만 가져오 는 게 좋 습니다',
#  '스 크 는 새벽 에 4 메가 는 그냥 넘 는 것 같 아요 ㅎㅎ',
#  '저희 회사 직원 분 베가 레이서 안습 ㅠㅠ',
#  '근데 베티 아 1 0 성 1 5 성 이렇게 사셨 다고 들 하 셔서 요 그분 들 이 거짓말 하 신 건가',
#  '아직 합의 중 인 듯',
#  '기변 신청 하늘 에서 별 따 기 네요 노하우 좀 아 시 는 분 알려 주 세요 꼭',
#  '좋 은 것 만 보 고 좋 은 것 만 배워 도 짧 은 인생 인데 1 9 1 1',
#  '주위 에 꽤 나 많 던데요 ㅋㅋ ㅋㅋ',
#  '좋 은 정보 는 츄 천',
#  '이보 사용 중 인데 와이브로 켜 면 배터리 가 빨리 닳 는 거 빼 곤 만족 중 입니다',
#  '됐 고 빨리 ICS 내놔',
#  '어제 글 램 금융 유심 으로 구입 했 는데요 gps 도 되 는 걸로 알 고 있 구요 그럼 당연히 티맵 도 되 겠 죠',
#  '그리구 이뻐요',
#  'AS 지원 은 확실 할 겁니다 2 0 0 만 명 이 넘 는데 겔 투사 용자 ㅋㅋ ㅋㅋ',
#  '갤 스 좋 긴 하 지만 법인 쪽 으로 만 4 5 에 0 원 많이 풀려서 왠지 사기 시러 져요 ㅠㅠ',
#  '저 는 케이티 드디어 젤리빈 먹 는군요',
#  '저 도 갤 삼 쓰 기 전 갤 치 디 썼 는데 배터리 가 ㅜㅜ',
#  '휴업 에 있 는 게 더 싸 네요 3 3 에 2 무',
#  '스 넵 9 9 9 확정 입니다 구 동영상 보 니 스 넵 이 라도 쓸 만 하 더군요 물론 약간 의 딜레이 는 있 지만 요',
#  '철회 가장 좋 은 선택 은 못 하 더라도 후회 없 는 선택 은 하 셔야죠 ㅋㅋ',
#  '전반 대로 아이폰 5 하드 에 안드로이드 가 돌 면 좋 겠 다는',
#  '아 이뻐 에게 사랑 을 듬뿍 주 세요 응',
#  'ㅋ 공지 도 유출 되 는 세상 이 군요 전 오늘 부터 되 는 줄 알 았 어요',
#  'NFC 키 셨 나요',
#  '마하 진저 되 고 나머지 제품 들 도 슬슬 올라갈 꺼 같 은데 ㅎㅎㅎ 스카이 보다 훨씬 안 좋 은 건 아닌 듯 ㅎ',
#  '갤 투 는 명기 죠',
#  '알프스 ㅋㅋ ㅋㅋ',
#  '배터리 도 병 이 죠 화면 은 더 병 ㅠ',
#  '싸이 천하 였 는데 기업 의 앞날 은 모르 네요 간만에 싸 이 들어가 서 마지막 정리 했 네요 ⓣ',
#  '디자인 에 싼 티 가 개성 도 너무 없 고',
#  '실물 아이폰 노트 당장 에 세 개 를 비교 하 면 원본 색 에서 가장 먼 게 노트 입니다 색재 현 율 까지 갈 것 도 없 고요',
#  '기대 가 됩니다 갤럭시 S 3',
#  '그때 쯤 이 면 손 에 다른 폰 을 들 고 계실 꺼 에요 ㅋㅋ',
#  '한진 택배 로 왔어요',
#  '갤럭시 탭 A with S 펜 VS 갤럭시 노트 1 0 1 2 0 1 4 Edition',
#  '갤 스 안 버리 면 갤 유도 따라가 죠 ㅋ',
#  '애플 천지창조 설 이제 좀 지겹 습니다 뭐 좀 참신 한 거 없 나요 ＊',
#  'LGU 갤럭시 S 3 LTE 사용 중 인데 가끔 씩 3 G 로 넘어가 네요',
#  '그래도 전 에 사모님 감동 시키 려고 당원 들 한테 뭐 물 어 보 고 그러 던데',
#  '아 혹시 해상도 고자',
#  '노트 화이트 지금 사면 9 9 만 원 이 떡 하 고 찍힙니다 ㅠㅠㅠ',
#  '지금 은 모르 겠 지만 원래 삐삐 사용 하 시 는 걸로 알 고 있 는데 ㅎㅎ',
#  '갤 4 미니 가 훨 더 낫 나요',
#  '취소 하 면 다시 신청 안 되 는데 ㅡㅡ 어찌 취소 를',
#  '부모 님 효 도르 갤럭시 S 3 3 g VS 갤럭시 그랜드',
#  '씨제이 홈쇼핑 에서 베가 레이서 1 파내 요',
#  '발열 이 심하 네요 겨울 에 나왔 으면 좋 왔 을 뻔 했 네요 손 난로 용 으로 그리고 최적 화면 에선 역시 좀 떨어지 네요',
#  'T 의 신 기술 이 라고 하 는 건 펨토셀 같 은데요 ㅋ',
#  '혐짤표시요 ㅠ ㅠ',
#  '삼성 스마트폰 부서 에 사원 으로 들어간 친구 는 몇 년 새 얼굴 이 반 토막 났 더군요',
#  '시리우스 선 개통 후 배송 ㅠㅠ',
#  '아 그렇 구나 많 은 걸 알 아 가 네요',
#  '저 도 베가 3 5 신규 만 하염없이 기달려 요 올무 로 ㅋㅋ',
#  '2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ',
#  '진짜 답답 하 다 답답 해 나 랑 아무 상관없 는 일 이 지만 ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ 방법 이 전혀 없 네 전혀 없 어',
#  '제 옵 삼 디 는 언제 진저 가 될까요 날짜 는 지났 는데 ㅠㅠ',
#  '아아 그런 어 플 을 써 본 적 이 없 어서 잘 안 받 는데 인터넷 으로 뭘 삿 더니 만 그 전화 인 줄 알 고 ㅋㅋ',
#  '1 때 최 인국 만 뜨 고 나머지 는 거의 묻힌 데 에 비해 이번 엔 거의 다 활동 하 네요',
#  '음 전 많이 안 난다고 생각 했 는데 ㅋ',
#  '1 5 1 6 일 신청자 분 들 은 7 월 중순 이 네요',
#  '1 7 만 원 은 LTE 였 죠 이거 2 주 정도 팔 고 있 는 정책 이 라 뭐 그닥',
#  '한데 모아 놓 고 옴팡지 게 때려 버리 고 싶 네요',
#  '번이 회선 이 있 으셨 나 봐요 전 신규 라 그냥 손가락 만 빨 고 있 네요 시리우스 가 좀 떨어져 줬 음 좋 겠 네요',
#  '좋 네요 부럽 ㅎㅎ',
#  'ㅋㅋㅋ 저거 해리포터 젤리 같 은데요 ㅎㅎㅎ',
#  '삼 일 동안 상품 1 개 올렸 네 ㅋㅋㅋ 2 8 8',
#  '아니 중고 나라 도 아니 고 뽐뿌 에서 ㅡㅡ 대박 이 네요 ㅜㅜ 사진 의 표시 와 벽돌 사진 너무 슬프 네요 ㅜㅜ',
#  '종료 네요',
#  '아몰 3 D 랑 옵 3 D 는 개념 자체 도 성능 자체 도 비교 할 대상 이 아닙니다',
#  '선불 심 끼우 고 사 은 받 은 거 로 치킨 시켜 드 심 됩니다 근데 요즘 선불 정책 이 없 네요 ㅋ',
#  '저번 주 월 욜 화 욜 개통 하 신 분 은 이제 얼마 안 남 았 습니다 어서 ㅋ',
#  '스카이 꺼 는 좋 아서 쓰 는 게 아닙니다 이뻐서 쓰 는 거 지',
#  '8 기가 로 나오 고 2 0 만 원 낮춰 주 세요 감사 합니다',
#  '아 팔 았 는데 뭔가 아깝 네요',
#  '안 나왔 어요',
#  '삼 쏭 그렇게 후 발주자 로 만들 고 도 이렇게 세계 적 으로 잘 파 는 거 보 면 참 대단 한 듯',
#  '맥스 가 좋 네요 문자 보낼 때 자주 쓰 는 문장 만들 어 놓 으면 문자 보내 기 편한 데 요 갤 S 는 이게 없 네요 ㅠㅠㅠㅠㅠ',
#  '여긴 어딘 가 여',
#  '그러 게 내수 차별 짓거리 하 지 말 고 중국 에 낼 때 그냥 동시 에 내 지 ㅡㅡ',
#  '1 0 번 넘 게 해서 평균 유 ㅠㅠ',
#  '유출 펌 이 라 그렇 지 않 나요 제발',
#  '할 부지 원액 이 무슨 뜻 이 죠 ㅠㅠ',
#  '휴 뽐 인 들 에게 미라크 는 4 만 3 5 3 개월 인 듯 ㅎㅎ',
#  '쿼드 코어 라고 무조건 좋 은 건 아니 죠 저 전력 저 발열 프로세서 라 아무래도 일반 피시 보다 좋 을 순 없 죠',
#  '갤럭시 노트 6 개월 의무 3 7 0 vs 3 개월 의무 4 7',
#  '서명 운동 1 0 0 0 명 넘 는 거 보 고 공개 한 것 같 네요',
#  '이제 생 폰 으로 쓸 겁니다 ㅋㅋㅋ 어차피 3 개월 ㄷ ㄷ ㅋㅋ 근데 TB 때문 에 ㄷ ㄷ',
#  '엥 케이블 이 아이 폰 용 으로 바뀌 었 네요 ㅇㅅㅇ',
#  '아 이건 출시 이훈 가요',
#  '냅두 시 는 게 정답 입니다',
#  '제 가 받 아도 될까요 ㅎㅎ',
#  '공기 기 로 기변 하 면 지원 받 을 수 있 습니다 타 판매자 일반 기변 은 안 되 구요',
#  '아직 도 갤럭시 s 쓰 는 분 있 을라나',
#  'LG 로 번호 이동 하 셔야 합니다',
#  '갤 투 가 명기 긴 명기 군요',
#  '월척 이 네요 ㅜㅠ',
#  '대신 시리우스 터치 는 정말 뭐 같 습니다 ㅡㅡ',
#  '약 일 주일 간 의 아이폰 6 사 용기',
#  '배터리 케이스 는 타 업체 의 제품 보다 저렴 하 네요',
#  '아이폰 쓰 지만 개방 과 국내 서 쓰 기 엔 안 드가 나 보여요',
#  '헐 완전 희생',
#  '약 정승 계 손자 ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ ㅎㅎㅎ',
#  '엇 머크',
#  '무슨 조화 일까요 sk 가 전파 중첩 지역 이 면 그럴 수 도 있 지만',
#  '엇 최적화 문제 인가 슈렉 카트 에서 는 차이 가 많이 보이 네요',
#  '여친 8 기기 써도 표시 되 던 대 유 플 ㅋ',
#  'lg 해지 한 지 3 년 이내 인가 1 년 이내 인가 그러 면 가 면 권 줘요',
#  '3 g 임 을 감안 해야죠 ㅋ',
#  '더 털려 도 정신 못 차릴 개티',
#  '갤 유 타 시 면 됩니다 2',
#  '맥스 에 이어 하관 이 최악 인 폰 이 죠 ㅎㅎ',
#  '엘지 가 왜 더 오래가 는 거 쥬 예전 폰 은 2 g 라 더 조금 간다고 알 고 있 었 는데유',
#  '전 플립 커버 로 밑 에 받치 고 쓰 다 보 니 발열 은 잘 못 느꼈 는데 ㅜ 지금 보 니 저 도 4 4 도 네요 ㅡㅡ',
#  '옵 두 배 좋 죠',
#  '베가 파일럿 1',
#  '이건 환불 이나 교환 될 수 있 는 건 이 아닌가요',
#  '갤 스파 구입 기념 입당 신고 합니다',
#  '4 시간 동안 3 0 프로 는 배터리 오류 가 아닐지 ㅋ 제 가 사용 하 는 건 그렇게 안 가 는데 ㅠㅠ',
#  '체력장 이 죠',
#  '명령어 가 틀렸 네요 3 8 4 5 모델 번호',
#  '지금 와서 는 있 다가 없 으면 많이 힘들 죠',
#  '바꿨 어요 ㅋㅋ 모두 에게 공평 하 게 드리 기 위해서',
#  '시간 내 서 해 봐야 겠 네요',
#  '아이폰 들 어 보 면 이거 떨어트리 면 골 로 가 겠 구나 느낌 이 딱 옵니다',
#  '갤럭시 노트 2 의 이 기능 을 뭐 라고 하 나요',
#  '로딩 이',
#  '노트 단종 시키 면 잘 팔릴 텐데 ㅋ',
#  '하 나이 먹 은 것 도 서러운데 ㅠㅠ',
#  '리뷰 하 신 분 이 얼굴 도 인증 하 셨 네요',
#  '아이폰 만 의 아이콘 수정',
#  '와 드디어 옵티머스 LTE 2 가 도착 했 어요 너무 좋 다 ㅠㅠ',
#  '그런데 실사 하 긴 아쉽 네요 ㅋ 할지 가 없 어 져서',
#  '저 의 어머니 가 2 년 그 후 저 의 세 컨 폰 사용 중 인데 문제 없이 잘 쓰 는 중 입니다 기계 마다 다른 듯 하 네요',
#  '스카이 사상 이 아닐까요 ㅋ 화이트 하단 부분 이 좀 에러 가 아닌가 싶 더라구요 ㅠ',
#  '비싸 긴 비싸 ㅠㅠ',
#  '역시 카메라 하나 는 스카이',
#  '갤럭시 s 3 를 산지 1 년 이 지나 고 S 빔 을 사용 해 보 았 습니다',
#  '중고 가 기준 으로 추가 금 더 받 으시 고 교환 하 세요 추가 금 없이 맞교환 은 큰 손해 입니다 from CLIEN',
#  '갤 투 고 가 유지 하 면서 넥서스 싸 지 길 바라 요 사 고 싶 은 폰 만 싸 지 면 되 니까',
#  '맞 습니다 서로 비교 해 보 고 맘 에 드 는 거 쓰 는 거 죠',
#  '넥서스 겠 죠 ㅎㅎㅎ',
#  '다른 분 들 보 면 말 이 다 달라서 요 어떤 분 은 노트 2 보다 빠르 다 어떤 분 은 느리 다 ㅎㅎ',
#  '속도 는 빨라요 ㅋㅋ 버벅 임 없 고요',
#  '위 추해 주 세요',
#  '루팅 펌 구하 셔서 오딘 으로 올리 시 면 편합니다 자세 한 건 맛 클 이나 각종 블로그 글 참고 하 시 구요 ＊',
#  'lte a 광탈 기대 해 봅니다',
#  'ㅋㅋ ㅋㅋ 아이디 를 보호 해 주 고 싶 은 뽐뿌 인 의 마음 입 니당 ㅋㅋㅋ',
#  '레이서 이 세요',
#  '네 정말 이쁘 죠',
#  '저 도 그게 왜 그랬 는지 이해 가',
#  'ㅋㅋㅋ 그래서 가족 만 태우 라는 명언 이',
#  '욕 만 먹 다가 잠잠 해졌 어요',
#  '아이유 와 갤럭시 노트 박스 와 아크 의 조합',
#  '아 ㅎㅎㅎ 제 명의 로 산 겁니다 뺏 어 간 갤 스가 제 명의 니 당연히 그리로 문자 가 가지 요 엉엉엉 ㅜㅜ',
#  '아 저 여',
#  '전면 2 0 0 만 아니 고 2 0 만 인가요',
#  '주말 이 기대 되 는군요',
#  '삼성 은 갤 쓰리 도 있 지만 유럽 에선 저 가 형 갤럭시 에이스 시리즈 가 대박 났었 죠 ＊',
#  '큰 어 뉘 늦 었 네요 ㅋ',
#  '주말 에 심보 시 길 기원 합니다',
#  '나 도 어서 스토미 끼워팔기 해야 하 는데 ㅠ ㅠ',
#  '떨어져 봤 자 4 7 6 0 0 원 이 죠',
#  '요즘 액정 은 죄다 카멜레온 인가',
#  '데니 보이',
#  'HD 2 면 갈 텐데요 약해요 약해 ㅎㅎ',
#  '스카이 는 뽑 기 가 중요 한 것 같 네요 어떤 사람 은 또 별 탈 없이 쓰 고 한 번 문제 생기 면 끝장나 고',
#  '헐 달리 고 싶',
#  '저 도 모토 로 이 유심 핀 부러졌 네요 수리 할 곳 도 없 어 폐기 했어요',
#  '넥스 추천',
#  '제 가 약 두 달 전 까지 햅틱 착과 같이 썼 습니다 그 정도 만 돼도 이렇게 까진 안 해요 ㅠㅠ',
#  '미라크 가 좋 나요 모토 글 램 이 좋 나 여',
#  '괜찮 은데',
#  '조약돌 을 모티브 로 했 으니까요 ㅎㅎ',
#  '다시 열리 는 게 아니 고 그 전 꺼 이제 개통 하 셨 다는 말씀 아니 신 가용 ㅡㅡㅋ',
#  '갤럭시 노트 케이스 인증 샷 이 에요 ㅋ 풀 화이트',
#  '노트 매력 있 죠 나름 말 이 죠 s 펜 도 괜찮 구요 단점 도 있 긴 하 지만 요',
#  '그런가요 ㅎ',
#  '갤 스 는 처음 에 도 별로 였 네요 오히려 갤 유나 갤 크 보다 떨어졌 음둥 업그레이드 되 면서 좀 나아졌 네요',
#  '너무 잘 팔렸 죠 신 의 질투 를 받 은 기기 라 그런 듯 ㅠ',
#  'ㅋㅋㅋ 그것 도 좋 지요 ㅎㅎ',
#  '베가 LTE 액정 논란 이 쫌 있 나요',
#  '시리우스 대박 이 네요 ㅋㅋ 추카 드립니다 시리우스 에 뭐 가 있 는지 엄청 잘 처 주 네요',
#  'in cell 터치 방식 을 적용 하 면서 생기 는 종 특입니다 ㅠ',
#  '우아 땡기 네요 ㅋㅋㅋ 요즘 왤케 다시 헬 지 로 가 고 싶 은지 ㅜ ㅜ 청개구리 인가 봐요 ㅋㅋㅋ ㅋㅋ',
#  '발표 는 2 월 이 거의 확정 입니다',
#  '감사 합니다 ㅎ from CV',
#  '베가 시리즈 루팅 최적화 해도 배터리 소모율 큽니다',
#  'SKT KT 모델 은 배터리 가 빨리 떨어진다고 합니다 배터리 시간 은 U 단말기 가 오래간다 네요 차이 가 많 나 더라구요 검색 하 시 면 원인 도 나올 겁니다',
#  'SKT 갤럭시 S 2 할부 원금 2 9 9 0 0 0 원 떴 네요 최저 가 타이',
#  '올인원 커플 요금제 가 1 1 월 1 일 출시 된답니다',
#  '저 도 노트 사 고 싶 은데 아직 아이폰 4 S 할 부도 남 아 있 고 ㅠㅠ',
#  '제값 다 산분 들 중 에 뽐뿌 모르 는 사람 많 을걸요',
#  '와 화질 좋 네요 느낌 도 있 고',
#  '시리우스 의 이런 증상',
#  '갤 3 4 3 검색 해 보 시 면 아 시 겠 지만 불 안정 한 게 정상 인 상황 입니다',
#  'ㅎㅎ ㅎㅎ 귀요미 죠',
#  '그러 하 다 고로 추천 한다',
#  '서비스 센터 에서 해 주 는군요',
#  '앗 사진 이 안 뜨 네요 수정 중 입니다',
#  '갤럭시 S 2 ICS 롬 을 입수 했 다고 합니다',
#  '오 이쁘 네요 카메라 괜찮 은 듯',
#  '쿼 티 의 옵 큐 에 한 표 던집니다',
#  '사후 지원 병신 인 헬 지 의 옵 레 기 를 왜 사 는지',
#  '노트 는 좀 밝 고 옵 티 이 는 좀 어둡 고',
#  '포 멧 을 하 고 해야 하 나요',
#  '갤 노트 2',
#  '축하 해요 곧 마이너스 부 왘',
#  '옴 냐 ㅋㅋㅋ 그때 데인 분 들 이 상당히 많 죠',
#  '저 는 스카 이 꺼 그냥 잘 쓰 고 잇 어요 나름 정 붙히 는 중 베 넘 파',
#  '맞 는 거 같 네요 반영 하 겠 습니다',
#  '케이스 업체 어디 인지 거래처 를 바꾸 지 그대로 쓰 나 보 네요',
#  '여러 샷 중 에 제일 잘 찍힌 사진 이 에요',
#  '나름 웃겨요 ㅋㅋㅋ ㅂ ㄱ ㄹ ㅇㅅ ㅋㅋ',
#  '아이콘 을 공유 받 고 싶 습 닏',
#  '미 추 어 버리 겠 네 뽐뿌 가 막 오 네요',
#  '1 6 개월 간 사용 한 5 2 종 스마트폰 정리 해 보 았 습니다',
#  '찡찡이 업체 믿 을 만 한가요 첨 들 어 봅니다',
#  '갤럭시 s 이름값 한다는 ㄷ ㄷ',
#  '삼성 폰 이 참 튼튼 하 긴 한 거 같 아요 옴니아 2 도 굉장 하 죠',
#  '갤럭시 s 2 이 글 이 정확 한지 는 잘 모르 겠 는데',
#  '목동 가 봤 자 별 효과 도 없 을 것 같 은데 엄마 맘 은 그게 아닌가 봐요',
#  '가오 갤 의 재미 는 제 가 알 고 마블 팬 이 알 고 북미 관객 이 알 지요 꺄악 늘 기다린 답니다',
#  '광고 의 힘 이 라고 봐요 ㅎㅎ',
#  '생산직 을 갔 어야 해 1 0 에 1 보단 1 0 0 에 1 0 이 ㅜ',
#  '갤럭시 s 3 탔 습니다',
#  '박살난 갤럭시 S',
#  '근데 오프 에서 일반 인 입장 에서 는 모토 로 이 디파이 보다 삼성 갤럭시 에이스 가 훨씬 우위 에 있 죠',
#  '뭔가 이상 하 내요 지금 갤 s 1 으로 개통 하 면 1 년 간 무상 as 라는 거 자나 요 ㅋㅋ ＊',
#  '근데 5 인치 도 아니 고 4 9 인치 라면 내포 하 는 의미 가 뭘까요',
#  '계절 마다 종류 별 로 만들 었 어요 옷 을 ㅎ',
#  '그래요 좌표 좀',
#  '이상 하 네요 저 도 잘 되 는데요',
#  'towelroot 설치 해서 실행 하 면 v 3 라고 뜹니다 보 니 at t 업데이트 같 던데요 from CV',
#  '하도 혁신 혁신 해 대 니 이 쯤 되 면 혁신 의 정의 가 궁금 하 군요 새롭 기 만 하 면 혁신 인지',
#  '큭 돌핀 젤리빈 대응 펌 안 되 있 나 보 네요 이러 면 한동안 기본 브라우저 써야 되 는데',
#  '안습 위 추 드립니다',
#  '요즘 핸드폰 들 이 다 비슷 하 게 생겨서 그렇 지 않 을까요',
#  '조용히 있 을까요 ㅋㅋ',
#  '동감 입니다 ㅠㅠ 그래도 리콜 해 주 니까 일단 이뻐 보이 네요 ㅋㅋ',
#  '베가 레이서 양품',
#  '언제 5 0 만 대 를 더 팔 았 대요 1 0 0 만 대 돌파 도 아니 고 할 것 라고 기사 본 것 이 바로 얼마 전 인데',
#  '이걸 3 3 5 만 원 주 고 아이언 2 로 바꿔야 하 는지 고민 되 네요 망해 가 고 있 는 팬택 과 대란 이 가능 성 때문 에',
#  '커터 로 유심 잘라 넣 으시 고 1 2 3 2 5 8 0 하 셔서 3 G 온 니 로 바꿔 주 시 면 됩니다 SKT 기준',
#  '머지않 아 나오 지 않 을까요 가 무 유무 가 바로 나오 면 가분 유후 로 산사람 들 배 아플 듯',
#  '시리우스 쓰 시 는 분 들 중 에',
#  '갤 유 는 눈 만 껌뻑 입니다',
#  '아님 노 원고 옛날 엔 온수 고',
#  '갤럭시 노트 1 케티 쓰 는데 스 크로 유심 기변 되 나요',
#  '2 4 개월 에 3 4 공짜 면 오프 에서 는 나름 싸 게 산 거 같 네요 3 6 개 원 이 면 ㅜㅜ',
#  '음성 녹음 되 나용',
#  '인터넷 창 에서 메뉴 눌리 면 색상 이 안 떠요 ㅠㅠ 아 답답 하 네요',
#  '횟 한 사발 해야 하 는데 ㅋㅋ',
#  '그래도 1 0 만 원 받 으렵니다 1 8 2 8',
#  '계속 전화 하 셔서 깨우 셔야 합니다 그분 생각 해서 님 이 추위 에 떠 실 수 는 없 잖아요 ㅜㅜ',
#  '1 8 원',
#  '정책 은 아니 고 출고가 낮 으니 재고 정리 하 는 거 같 아요 지즈 원 보다 출고가 가 한 1 0 만 원 차이 나 나 봐요',
#  '옛날 에 호환 샀 더니 엄청 금방 끝나 서',
#  '방수 폰 이 라고 언 플 만 안 하 면 이런 논란 이 없 을 듯 하 네요 왜 방수 폰 운운 해서 사 서 고생 하 는지',
#  '아 댓글 이 넘 많 아서 정신 이 없 더군요 ㅈ ㅅ',
#  '기본 사용 은 다 됩니다 ㅡ from CV',
#  '프라다 공기 계 8 만 원 짜리 ㅎㅎ ㅎㅎ',
#  '여자 는 뷰 인가요 손 이 작 으면 어 케 통화 하 져',
#  '아 지금 막 남동생 꺼 블랙 으로 했 는데 화이트 가 나 을 라나요 ㅠ',
#  '잠깐 만 옵티머스 LTE 2 를 팔 고 이보 를 사용 하 면 삼성 3 2 gb 클래스 1 0 msd 카드 는 어쩌 나',
#  '네 괜찮 습니다 그런 거 안 보 세요 ㅋ',
#  '저 도 집 에 옴니아 1 이 한 대 굴러다니 는지라 잘 알 죠 ㅋㅋ',
#  '넥 7 lte 랑 갤 3 lte 결합 은 어떻게 하나 요',
#  '이동식 디스크 방식 선택 가능 한데 일일히 선택 해 줘야 하 니 그런 불편 함 도 있 네요 ㅎ',
#  '네이버 카페 가 보 셔 욤 공구 하 던데',
#  '집 청소 나 그리 하 지 ㅡㅡ',
#  '이분 채소 부처 님 ㄷ ㄷ ㄷ',
#  'ㅎㅎㅎ 그렇 긴 해 여 ㅠㅠㅠ',
#  '갤럭시 S 2 vs 갤럭시 넥서스 제 개인 적 인 생각 입니다',
#  '테크노 마트 에서 3 0 초반 에 6 5 개 통 은 봤 는데 지금 테크노 마트 영업 안 해서',
#  '글쎄요 그게 왜 맞 는지 에 대해서 설명 이 없 으시 네요',
#  '스카이 발적 화 에 한 번 데이 면 오 만정 이 떨어진다는',
#  '제 친구 는 딸 쌍둥이 벌써 부터 머리 터지 는 중',
#  '섭 스 센터 가 서 액정 교체 하 세요 저 도 그랬 는데 교체 하 고 나 니 그런 거 없 어요',
#  '효도 폰 으로 최 곱 니 다 아버지 가 매우 만족 해 하 셨 죠',
#  '남식 이 요',
#  '옵 큐 는 나오 기 좀 힘들 지 않 을까요 옵 큐 는 안 파 는 게 아니 라 못 만들 어서 없 다는군요 ㅡ ㅡ',
#  '우린 이 사진 을 몇 번 을 더 봐야 할까요',
#  '관심 끊 고 삿 시 는 게 마음 이 편해요 마치 예전 에 주위 사람 PC 는 내 가 다 고친다 이런 느낌 요',
#  '아 마이 폰 인가 뭔가 하 는 거 요 ㅋㅋ',
#  '그래서 그냥 오딘 으로 올립니다 키스 자체 가 컴 터 에 재앙 임',
#  '이제 대화 는 여기 서 대 댓글 금 지요 ㅋㅋ',
#  '⑩ 번',
#  '쿨 한 결정 입니다 결론 은 차이 없 다 ㅎ',
#  '저 는 티타늄 백업 으로 옮기 고 있 습니다',
#  '포 에스 오줌',
#  '엘지 갤 노트 화이트 나왓 나요',
#  '부모 님 스마트폰 으로 옮길 예정 인데 4 3 인치 갤럭시 S 2 베 가 레이서 테이크 타키 중 고민 입니다',
#  '배 가 레이서 넼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '저 같 으면 갤 3 로 가 겠 네요 옵 뷰 2 는 저 장소 버그 가 있 어서 꺼려 지 네요',
#  '5 열 배 치 면 화면 이 어느 정도 크 다는 말 이 군용',
#  '3 d 에 유난히 집착 하 네요 LG 는 옵 3 d 도 망했 는데',
#  'lte 를 한번 꺼 보 시 는 것 도 mp 3 스트리밍 정도 는 3 g 로 도 무난 하 더군요 with ClienS',
#  '아 싸 좡 님 이 요',
#  'd 급 이 면 ㅎ',
#  'ㅠㅠ 카메라 액정 이 제일 큰 문제 인 거 같 아요 발열 이나 배터리 는 다른 스마트폰 도 뭐 그렇 다고 들 하 니',
#  '통신사 가 어떻게 돼요',
#  '위약금 1 0 0 만 원',
#  '베 가 뽐뿌 좀 잠재워 주 세요',
#  '아무리 베가 LTE 가 구려 도 갤 S 보다 는 낫 지 않 나요',
#  '숨겨왔 던 나 의 수줍 은 나 의 글 램',
#  '윗분 말씀 보 니 하 긴 액정 크 고 비슷 하 게 생긴 아몰레드 해드려 도 되 겠 네요',
#  '스카이 기사 들 이 조금 불 친절 한 듯 삼성 이랑 비교 되 요 ㅋ',
#  '웃음 밖에 안 나오 네요 상대 안 해 드리 겠 습니다',
#  '갤럭시 노트 vs 옵티머스 뷰',
#  '쿼 티 에게 미안 하 군요 미라크 와 비교 되 다니',
#  '대략 SK 로 6 5 만 이 개 통했 나 보 군요',
#  '루팅 이 답 이 저',
#  '같이 기다려 봐요 근데 별 준다고 해도 탈지 후 부가 도 한 번 도 안 달려 봐서 유지비 가 ㅋ',
#  '무리 수다 화이 트 면 충분 한데',
#  '갤럭시 노트 나 시리즈 요 ICS 통화 최근 기록 너무 불편 하 네요',
#  '5 개 인데 나쁜 놈 하 고 나쁜 놈 아들 비행사 스토미 하나 모지',
#  '이러 다가 매해 같 은 말 나오 겠 네요 갤 3 출시 아이폰 5 나옴 갤 3 진짜 아니 다 악순환 의 연속',
#  '3 g 모델 로 나왔 으면 좋 겠 어요 ㅠㅠ 아니 면 3 g lte 모델 따로 두 가지 로 출시 하 는 것 도 괜찮 구요 ㅠ',
#  '헬 지 갤럭시 S 2 개 통 철회 했 습니다',
#  '멀티 터치 라 게임 은 안 하 는 편 이 지만 그래도 걸리 긴 하 네요',
#  '감사 합니다 줄 섭니다',
#  '갤 투 는 마이너스 정도 나와야 탈 듯',
#  '젤리빈 올려 보 고는 싶 은데 플 래쉬 가 안 돌아가 서 고민 중 이 네요',
#  '내 가 타 고 만 다 ㅋㅋ',
#  '리버 젼 A 라고 배터리 많이 달 고 잉여 스러운',
#  'apex 런처 가 루팅 안 해도 되 나요 설치 하 고 나 니 루팅 하 라는 메세지 가 나오 던데',
#  '화면 분할 사실 이 죠 어떻게 나올지 는 나와 봐야 알 것 이 고 아 샌 이 5 월 에 는 나오 려나 봅니다 ㅋㅋ',
#  '갤 스랑 옵티머스 2 x 오늘 이후 포 풍 하 락할 거 같 습니다',
#  '전 잘 썻었는데 배터리 가 좀 아쉽 긴 했 엇 죠',
#  '젭라 엑시노스 에 3 G 로 LTE 넣 으려고 스펙 다운 을 하 다니 스냅 듀얼 LTE 는 셀 록스 로 충분 하 지 않 나',
#  '저렴 한 리퍼 액정 가시 는 것 도 괜찬을득합니다',
#  '2 9 9 도 있 었 나요',
#  '아니 에요 취하 지 않 았 어요 멀쩡 했 어요 다만 깜빡했 을 뿐 입니다 ㅠ ㅠㅠㅠ술먹고 취해서 폰 잃어버렸 다고 하 지 마세요 제 자신 이 초라 해집니다 ㅠㅠ',
#  '빠른 겁니다 글고 백만 대 자체 도 대단 한 거 에요',
#  '오 홋 아바타 인코딩 해 놓 고 잠들 었 습니다 드레 곤 길들이 기 도 해 봐야 겠어요 ㅋㅋ',
#  '안드로이드 ios 아이 팟 인터넷 속도',
#  '베레 2 사용 하 면서 그런 적 은 없 었 네요 불량 맞 는 듯',
#  '헐ㅋ 한번 더 하 는 건가요 ㅋ',
#  '연락처 부터 받 으셨 네요 ㅎㅎ 추 천 드려요',
#  '전 2 만 원 넘 는 건 줄 알 았 네요 걍 버리 세요',
#  '베가 레이서 U 모델 7 8 0 L ICS 업 글 시작 되 었 네요',
#  '한 7 인치 는 되 어야지 멀티미디어 기기 가 될 듯 ㅋ',
#  '시리우스 가 할 부 지원 이 면 할 부 이자 5 9 도 들어가 지 않 을까요 스 크 는 무조건 싫 어서 넥 원 이 사요 저라 면',
#  '에이스 용케 2 년 쓰 셨 네요 ㅎㅎ',
#  '작년 9 월 에 갤 3 1 7 만 대 란 일어났 잖아요 ㅋㅋ',
#  '제발 나왔 으면 좋 겠 네요 5 5 인치 나오 면 5 s 에서 바로 넘어갑니다 ㅋ',
#  '미라크 쓰 시 는 분 들 펌웨어 업 글 하 세요',
#  '그런 가요 낚 시 ㅠ',
#  '전면 이 강화 유리 로 되 어 있 나요',
#  '화이트 와야 하 는데',
#  '아이폰 에서 Mate 7 으로 넘어왔 습니다',
#  '탭 보 고 노트 인 줄 알 았 서',
#  '아 부인 할 수 가 없 음',
#  '저 는 3 천 원 짜리 쿨 케이스 입니다',
#  '순간 오지랖 이 발동 되 서 ㅋ',
#  '갤럭시 S 에 대한 일화',
#  '액정 만 깨져도 찾 아 줄 텐데 너무 파손 이 심해서 찾 아 주 고 도 골치 아파 질까 바 그냥 버렸 네여',
#  '뽐 정모 ㄱ ㄱ ㅋㅋㅋ ㅋㅋ',
#  '헉 글램 gps 없 나요',
#  '예은 애비 님 이 저 한테 고맙 다고 준다고 했 어요',
#  '하지만 전 옵 티 이 2 를 쓸 거 라 능거',
#  '막상 그렇게 되 도 좀 더 좀 더 하 면서 기다리 게 되 죠 ㅋㅋ',
#  '설마 필름 도 안 붇 이 고 썼 나요',
#  '갤럭시 s 3 대기전력 이 버그 였 군요',
#  '옵티머스 3 D 가 최고 속도 삼성 팬택 발끈',
#  '이미 안 에 칩 메인 기판 디스플레이 부품 에 파인 세라믹 이 쓰이 긴 합니다 아마 부품 배치 를 바꾸 겠 죠',
#  '그래서 문제 없이 잘 처리 하 셨 나요 혹시 사용 하 신 건 아닌가요 ㅜ',
#  '그럴듯 하 네요 ㅋㅋㅋ',
#  '옴니아 안드로이드 입니다',
#  '팔아먹 을 땐 신나 게 팔아먹 고 내쳤 죠',
#  '둔산 가 세요 거기 서 싸우 지 마시 고',
#  '누나 가 kt 기변 으로 4 0 만 짜리 베가 레이서 생각 하 는 중 인데 괜찮 을까요',
#  '아마도 그렇 겠 죠',
#  '갤럭시 s 3 이 아이 폰 3 세대 가 되 네요 ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋ ㅋㅋ',
#  '별거 없 어요 동영상 도 ㅎ',
#  '이트 레이드 갤럭시 S 2 지난번 SK 증권 대란 보다 더 개념 인 듯 어서 달리 세요',
#  '헐 이건 좀 아니 다 싶 네요',
#  '최신 펌 이 에요',
#  '고객 님 여름 에 시원 하 시 라고 집 어 넣 은 건 아닐까요',
#  '갤 2 를 i 9 1 0 0 으로 바꿔서 CM 1 1 쓰 고 있 는데 정말 좋 네요',
#  'htc one 에 스텔스 모드 가 있 었 나요 ㅎㅎ',
#  '막 찍 어도 잘 나와서 4 s 좋 습니다 갤 3 은 주위 에 없 어서 모르 겠 네요 ㅋㅋ',
#  '아이코 리플 들 감사 합니다 백업 해 놓 고 공초 해 보 겠 습니다',
#  'ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋ ㅋㅋ 폰 바꿀 수 있 을까요 ㅠㅠ',
#  'LED 관련 해선 무궁무진 한 커 스터 마이 징 을 지원 하 는 어 플 이 에요 써 보 세요 마켓 에 있 어요',
#  '혹시 어제 갤럭시 호 핀 분실 하 신 분 계신 가요',
#  '힐 을 빼 도 비율 이 쩌 네요 ㄷ ㄷ',
#  '헬 지 혐오 하 게 된 계기 가 되 었 죠',
#  '옷',
#  '어딜 보 고 있 나',
#  '뒷배경 이 검 은 색 이 라 ㅋㅋ 뭐 가 제일 맘 에 드 시 나요',
#  '폭시 어떤 폰 받 으셧 나 요 with ClienS',
#  '잡스 시절 의 아이폰 이 그립 네요',
#  '효도 르 로 는 갤 투 좋 죠',
#  '출고가 그대로 일 듯',
#  '개인 적 으로 감압 식이 치명 적 인데 디자인 으로 참고 일 년 쓰 렵니당',
#  '세로 크기 가 줄 었 다면 가로 크기 가 늘 어야 같 은 3 7 인치 가 되 겠 죠',
#  '정식 버 젼 에 와서 는 타이핑 문제 는 못 느꼈 네요',
#  '나눔 고 딕 좋 네요 갤럭시 S 2 S 2 노트 1 2 용 탭 1 등',
#  '저 는 고민 많이 하 다가 물리 홈 버튼 있 는 옵 이이 로 갔 네요 별거 아닌 거 같 은데 차이 가 꽤 크 더라고요',
#  '흠 그렇 군요 낯간지럽 지 않 을까요 쩝',
#  'USIM 만 바꿔 끼 시 면 일반 적 으로 APN 설정 도 알 아서 되 고 문제 없이',
#  '별 ㅋㅋ',
#  '홈 화면 인터넷 은 너무 넘사벽',
#  '채권 료 면제 를 잘못 말 한 게 아니 라면 ㅋㅋ ㅋㅋ',
#  '와 키보드 에 대한 이야기 가 많 네요 ㅎㅎ ⓣ',
#  '갤 3 는 주황색 이 네요 ㅋ',
#  '에 Dmb 도 다른 가요',
#  '3 m 너 고소',
#  '그 부분 을 확인 못했 군요',
#  '아하 정지 화면 일 때 가 문제 인 거 였 군요 제 가 잘못 알 고 있 었 습니다',
#  '6 0 1 까지 는 해 줬 죠 지켜봐야 죠 안 할 확률 이 높 지만 ㅋ',
#  'kt 갤럭시 s 2 인터넷 속도 좀 봐 주 세요',
#  '갤 투 에 한 표',
#  '베 가레 이 서 쓰 는 동생 이 이런 말 을 하 네요',
#  'd 카페 sk 갤럭시 s 2 공지 는 올라왔 지만',
#  '엠 보트 에서 연락 했 나 봅니다 이젠 안 해 준다 네요',
#  '삼성 은 기대 도 안 합니다 차라리 구글 을 기대 하 는 게 낫 지',
#  '일단 3 일 만 써 보 세요 ` ㅡ `',
#  '갤 삼 써서 그런지 뭔가 어색 해 보이 는 그런 느낌',
#  '네 그런 것 같 아요',
#  '갤 호 핀',
#  '갤 투 때 가 최고 네요',
#  '오 저 랑 폰트 취향 이 같 으신 분 들 이 ㅎㅎㅎ from CLiOS',
#  '몇 년 이내 엔 힘들 거라 봅니다',
#  '즉시 개통 가능 한 곳 많이 있 는 걸로 아 는데',
#  '와이맥스 칩 주파수 가 틀려서 칩 바꿔야 될 텐데 출시 하 려나요 와이맥스 랑 모바일 와 이맥스 랑 좀 달라서',
#  '그건 스마트폰 아니 지 않 나요 …',
#  '갤 삼 사진 찍 는 사람 으로써 갤 삼 꼴 지는 옵 g',
#  '옵 지 가 사진 이 밝 아서 더 구려 보이 지 둘 다 구려 보이 는데요 흠',
#  '아무 상관 없 습니다',
#  '갤 3 3 g 모델 어떤 가요',
#  '멀티 캐리어 는 칩 이 안 되 서',
#  '글 을 읽 지 는 않 았 는데요 눈 아파요 ㅠ 개취 죠 머 로이 쓰 는 저 는 머 가 되 나요',
#  '핸 폰 바꾸 려니 어렵 네요',
#  '운송장 번호 뜬 거 어 케 확인 하 나염',
#  '아 배터리 용량 깜빡했 네요',
#  '요금제 가 6 2 요금제 에 3 개월 이 기 때문 에 1 만 원 정도 차이 나 더라구요',
#  '실망 이 네',
#  '감압 식 이 었 죠 전 모토 로 이 사고 친구 는 시리우스 를 샀 더랬죠',
#  '오오 자세 한 리뷰 잘 봤 어요 혹시 노트 에서 pdf 파일 볼 때 pdf 파일 읽 으면서 바로 필기 하 고 줄 그으면서 볼 수 있 나요',
#  '삼성 실질 적 플래그 쉽 기기 가격 도 제일 비싸 기 도 하 고 ㅋㅋ 점점 s 시리즈 는 하이엔드 형 보급 기화',
#  '임 셔틀 중 고 삽니다 혹시 팔 사람 9 6 5',
#  '코 로 원래 그래요',
#  '얼마 안 남 았 네요 ㅋㅋ',
#  '밝기 몇 으로 네트워크 는 멀 로 하 셨 나요',
#  '황당 하 네요 소비자 과실 강하 게 나가 셔야 해요 후기 도 궁금 하 네요',
#  '음 근데 야간 에 뭉개지 는 마치 수체 화 현상 은 여전 하 다고 들 었 는데 야간 사진 은 어떠신가요',
#  '갤럭시 노트 불편 하 네요 ㅜㅜ',
#  '저 도 종종 그러 더군요',
#  '아 그런 가요 ㄷ ㄷ',
#  '링크 로 바꿔 주 세요',
#  '갤럭시 s 호 핀 플 래쉬 가 없 는 거 였 군요',
#  '이런 건 질문 게시판 가시 면 전문 답변 맨 들 이 답변 해 주 실 겁니다 아마추어 로서 한 마디 하 자면 노트 나 갤 2 로 해 드리 세요',
#  '회사 경영 을 진짜 쉽 게 생각 하 는 사람 들 이 많 네요 ㅎㅎ',
#  '큰 게 좋 지요 ㅋㅋ',
#  '무슨 삼성 푸쉬 관련 어 플 같 기 는 한데 Scloud 가 범인 인가 보 네요 아무튼 전후 차이 가 너무 나 요',
#  '사후 지원 은 팬 텍 이 엘지 보다 한 수 위 네요 ㄷ ㄷ 엘지 도 좀 분발 했 으면',
#  '베레 가 팬택 먹여살렸 는데요',
#  '갤럭시 노트 배터리 제조사 가 어디 죠',
#  '플라이어 가 ㅋ 들리 는 말 에 의하 면 필기 감 도 플라이어 가 더 좋 다던데 으',
#  '지금 사 면 됩니다',
#  '성능 도 그 닥',
#  '중저가 핸 펀 중 에 갤럭시 a 7 2 0 1 6 형 어떤 가요',
#  '지난달 에 끝난 옴니아 2 할부금 볼 때 마다 마음 이 아프 네요 ㅠ',
#  '그냥 케 바케 인 거 같 아요 ㅋㅋ 휴재 폰 만족 할려면 조립',
#  '아쉽 네요 카메라 에서',
#  '차 칸 대리점 이 네요',
#  '갤럭시 S 시리즈 변천사',
#  '눈 퇴 갤 공감 한 표',
#  '오 만드셨 군요 축 하 드립니다 저 도 다이소 3 군데 다니 며 살펴보 았 는데 저 다이어리 가 가 성비 가 젤 좋 더라구요 즐거운 독서 생활 하 세요',
#  '으허허 헝 somebody help me 1 2 5 5',
#  '사례금 이 라도 1 2 만 원 좀 주 지 싸가지 없 는 xxxxx',
#  '갤 투도 명 긴데 ㅜㅠ',
#  '엊그제 서비스 센터 가 서 최신 버전 으로 업데이트 를 했 는데 최신 버전 효과 인지 아니 면 초기 화 효과 인지 버벅 이 던 게 덜하 네요',
#  '갤 삼 쥐 가 줄 섭니다 이건 제 껍니다',
#  '갤 놋 사용 자 인데 저라 면 노트 갑니다 다시 선택 해도 요',
#  '저희 집 이 인터넷 이 안 좋 아서 그런가 왜 케 끊 켜 요',
#  '폰 드림 검색 해 보 세요',
#  '이걸 보 고 아이폰 닮 았 다고 하 는 게 눈 이 정상 이 아니 니까 그런 듯 ㅋㅋ ㅋㅋ',
#  '나름 괜찮 네요 ㅎ',
#  '휴대폰 장터 에 매물 이 잘 나오 더군요',
#  '지피 유도 중요 한 부분 이 구요',
#  '이건 터치 도 안 먹히 는 먹통 이 되 는 ㅠㅠ',
#  '휴 뽐 이 니까요 괜히 돈 이 비싼 게 아님',
#  '테이크 심히 땡기 는데요',
#  '제 생각 은 옴니아 가 쓰레기 가 아니 라 윈 모 가 개 객 끼 죠 ㅜㅜ',
#  '댓글 을 지울 수 도 잇 고 머 이런 저런 문제점 이 있 는 이상',
#  '액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ',
#  '터치 는 다 되 고 줄 만 한 줄 갔 네요',
#  '카톡 보낼 때 대박 빠르 겠 다 저런 블 투 키보드 는 얼마나 하 나요',
#  '걍 물결 효과 이쁘 게 하 려고',
#  '글 쓴 님 찾 으신 추첨 기 에요 http tools gyuyeon com random picker',
#  '청소기 돌리 실 때 라도',
#  'ㅋㅋ 남자 는 핑크 죠',
#  '가 면 채면 에 요금제 가 자유 여야 올무 입니다 이것 은 요금제 가 4 5 로 묶 여야 되 서 올무 가 아니 죵',
#  '둘 다 안 팔리 는 폰',
#  '플라자 에서 바로 해 주 기 도 한다고 하 지만 택배 가 편해서 그리 했 습니다 착불 로 진행 해 주 더라구요 ㅎ',
#  '갤럭시 S 2 결국 두 번 째 교 품 신청',
#  '옵티머스 3 D 이쁘 네요',
#  '원금 도 더 쌉니다 ㅎㅎ',
#  '아 베가 s 탔 는데 저 와 는 다른 세계 듀얼 코어 더 누가 엘 티 이 세계',
#  '기다리 던 게 나왔 네요',
#  '컴 터로 하 다가 댓글 확인 하 다가 에이 하 고 누웠 지만 폰 으로 보 고 계시 잔 슴',
#  '화질 까지 는 자세히 못 봤 네요 우선 제로 셔터 랙 은 좋 은 거 같 네요 역효과 가 있 군요',
#  '저 두 신규',
#  '베가 레이서 랑 이 보랑 고민 중 이 네요',
#  '안타깝 지만 어차피 번인 은 종 특이 라 얼마 못 가 서 또 생깁니다',
#  '영국 에서 공개 된 삼성 갤럭시 S 3 가장 유력 한 디자인 블랙 화이트 jpg',
#  '갤럭시 S 3 슬림',
#  '마침내 질렀 습니다 갤럭시 노트 ㅎ',
#  '전 커서 ㅜㅜ',
#  '포장 도 사람 이 하 는데 지문 묻 을 수 있 겠 죠',
#  '적절 하 네요 저 는 프로 푸 스 오버클럭 갑니다 디파 잉 디파 잉',
#  '와이파이 로 업데이트 할 수 있 는 건가요 잘 몰라서 질문 드려요 ㅜ pc 로 만 올릴 수 있 는 건지 요',
#  '전 옴 케어 로 6 0 에 ㅋㅋ 7 월 달 에',
#  '그럼 도로 가져가 서 우체국 에 맡길 테 니 알 아서 하 세요 하 기 엔 또 택시 비 가 아깝 죠 ㅡㅡ',
#  '베가 레이서 1 1 1 성 나오 면 무조건 탑 니다 ㅋㅋ',
#  '뭐 할 말 이 없 네요 ㅋㅋ ㅋㅋ',
#  '5 월 까지 는 기다려야 겠 네요 ㅋㅋ',
#  '유통망 마다 다름 진짜 큰 업체 들 중 코 웍 을 본사 와 따로 할 수 있 는 업체 만 가능 한 리 베임 돠 손가락 에 뽑힐 정도',
#  '교 품 은 빨리 해 주 는 것 같 던데 아닌가요 빨리 문 의 전화 독촉 전화 를 넣 으시 길',
#  '미라크 다 좋 은데 역시 cpu 가',
#  '아 샌 할 때 도 아 샌 이 마지막 이 라고 했었 죠',
#  '삼성 중저가 갤럭시 S 3 미니 출시 예정',
#  '기억 은 잘 안 나 네요 싼 만큼 가입비 는 있 었 을 것 가 튼 데 요 하여튼 빨리 풀렸으면 하 네요',
#  '남편 도 은근 가 기 귀찮 아 하 는 듯 ㅎㅎ',
#  '옴니아 1 쓸 때 가 생각나 네요 전지전능 했 는데',
#  '옵 원 번 이 2 2 베가 s 기변 1 2 8 요 자 3 2 일 기다립니다',
#  '갤럭시 노트 도 리 락 이 가 있 군요 ㅎㅎ 귀여워 요',
#  'ㅎㅎㅎ 귀여우 시 네요 ㅎㅎㅎ',
#  '그래서 전 테티 이 씁니다 아무 도 안 가져 갑디다 ㅎㅎ',
#  '뭐 sk 도 마찬가지 아닌가요 지방 에 LTE a 망 도 안 되 면서 기기 부 타 팔아먹 은 sk 나 kt 나 다 똑같 은 xx 들 from CLIEN',
#  '기본 홈 에 있 습니다',
#  '지 는 유 아주 아주 핑크 빛 에 러블리 하고 블링 블링 빤딱빤딱 한 이미지 를 생각 하 고 있 는 데 쿵쿵따 ♬',
#  '오호 지금 바꿀 건 아니 지만 가입 가입',
#  '루팅 하 면 카운트 들어가 고 초기 화 해도 걸리 지 않 나요',
#  '압도 적 이 죠 대용량 배터리 가 옵션 으로 나와 주 기 만 한다면 이만 한 동영상 머신 도 없 을 겁니다',
#  '런 쳐 사용 하 면 젤리빈 은 의미 없 나요 갤럭시 S 2',
#  '눈 앞 1 cm 에서 폰 두 고 쓰 시 는지 일상 생활 에서 티 도 안 날 거 같 은데',
#  '전담 AS 기사 ㅊㅋ 합니다 ㅋㅋ',
#  '으 허 ㅓㅓㅓㅓㅓㅓㅋㅋ 떨어져라',
#  '전국 국립 을 다 소화 할 수 는 없 을 꺼 같 은데 무슨 순서 로 할지 궁금 하 네요',
#  '옵 3 d 는 계속 떨어지 죠 안 팔리 는데 재고 가',
#  '그건 특별 한 거 고 이게 인터넷 최저 가 일 듯',
#  'ㅠㅠ축하드려요 저 도 갤 s 3 인데 갤 놋 5 까지 버텨 봅니다',
#  'DND 시리우스 취소 됬 어요 ㅠ ㅠ',
#  '어 엇 감사 드려요 점심 먹 고 느긋 하 게 가 야 겟 어요',
#  '엇 베 갈삼 중 고 나라 에서 테두리 깨진 거 많이 나오 는 거 같 아요 ㅎㅎ',
#  'ㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#  '오 좌표 부탁 드려요',
#  '베 가레 이 서 아주 좋 아요',
#  '살 쾍이님도 디파이 나 베 가 기다려 보 죠 ㅋㅋㅋ',
#  '갤 3 핫 스팟 을 통해 아이폰 이나 패드 사용 이 안 되 나요',
#  '그러 게 요 뭘 먹 었 길래',
#  '3 년 쓰 는 거 자체 가 에러 고요 바꿔 줘도 남 은 할부금 새기 기 에 얹 을 것 같 네요',
#  '3 gs 가 훨씬 쾌적 합니다',
#  '모마 가 되 는군요 저게 ㄷ ㄷ',
#  '그러 네요 옵 이 이 모서리 로 발등 찍히 는 생각 하 니 아이 고 ㅠㅠ',
#  '정말 엄청나 게 나아졌 죠 천지개벽 수준',
#  '화이트 랑 민트 가 잘 어울리 네요',
#  '번이 라서',
#  '전 이미 가 봤 는데 늦 게 봐서 품절 됐 네요 ㅠ ㅜ 몇 일전 부터 기다렸 는데 베가 랑 은 인연 이 없 는 듯 ㅠ ㅜ',
#  '오늘 은 늦 었 고 내일 배틀 떠야 겠죠 감사 합니다 ㅜㅜ',
#  '아이폰 5 배터리 광탈 이 라는데 저 는 괜찮 네요',
#  '옵티머스 3 D 큐브 이야기 입니다',
#  'ㅎㅎ 어서 가방끈 이 풀리 길 기다림 니다',
#  'ㅠ ㅠ아이폰에도 있 었 으면',
#  '갤럭시 s 2 hd lte 스냅드래곤 던전 디펜더 구동 영상',
#  '일요일 에 일반 유심 마이크 로 유심 으로 정보 변경 가능 한가요',
#  '노트 가 진리',
#  '잡담 갤럭시 노트 3 월 2 4 일 인스 빌 꺼 구매 했 는데 글 이 사라졌 네요',
#  '지금 갤럭시 S 쓰 시 는 분 들 한테 는 좀 죄송 하 지만',
#  'KT 갤럭시 S 2 SKT 유심 에서 완벽 합니다',
#  '가격 이 지금 이랑 같 다면 올해 나온다면',
#  '아이폰 6 s 써 보 니 갤럭시 s 2 생각 난다고 하 면',
#  '이런 부탁 드 랴 도 될진 몰 겟 지만 베 넘 파 하나 가능 하 시 다면 ㅠㅜ',
#  '배터리 경찰서 에 주 면 이상 하 게 쳐다볼 듯 ㅜㅜ',
#  '아이폰 을 사 는 건 감성 을 사 는 겁니다 사과 그림 만 따지 는 사람 이 있 잖아요 물론 그런 사람 이 극히 일부 일거 라 믿 습니다',
#  '옴니아 문제 인가요 윈도우 모바일 문제 인가요',
#  '신규 로 1 6 에 올무 라 ㅎㅎ',
#  '커미션 이 데 쉐 유심 4 개 중 에 2 개 인 거 군요 ㅎㅎㅎ',
#  '이거 참 고민 인 건데 ㅋ',
#  '순정 으로 쓰 고 싶 다면 겔 투 죠 편의 성 이 더 좋 습니다 그 외 는 겔 넥',
#  '대단 하 네요 제 5 광 은 언제 쯤',
#  '괜찮 네요 ㅋㅋ sky 의 옵 원 망해라 스킬 시전 ㅋㅋ',
#  '초보 자 도 알 기 쉽 도록 꼼꼼 하 게 설명 잘 해 주 셔서 고맙 습니다',
#  '갤럭시 S 3 노티 바랑 소프트 키 위치 가 별로 에요',
#  '볼 매 둥글이',
#  '같이 허 탈해 질 껏 같 지만 괜찮 은 걸로',
#  '절전 모드 도 해제 하 셨 나요',
#  '할부금 8 5 만 2 4 개월 5 5 요금제 어휴 누나 가 몇 일전 에 그 조건 으로 s 2 를 삿 는데 ㅠㅠ',
#  '헉 지문 방지 필름 주문 했 는데 뭘 죽인다는 건가요 자세히 답변 좀 부탁 드릴게요 ㅠ',
#  '2 0 1 8 년 부터 OLED 아이폰 나온다',
#  '우와 잘 찍 으시 네요 기계 가 사람 가리 나 봐요',
#  '감사 합니다 근데 저거 볼거리 도 있 고 속도 도 볼 만 한 가요',
#  '확실히 갤 s 보다 1 0 0 배 낫 다',
#  '갤럭시 S 2 화이트 가 나왔 네요 ㅋ',
#  '전갤 넥 인데 저 도 그런 경험 이 몇 번 있 습니다 ＊',
#  '없 어요',
#  '저 도 오늘 대리점 을 갔 는데 시리우스 가 있 더라구요 목각 인 듯 했 지만',
#  '저 는 정전식 이 포 풍 오타 율 이 ㅠㅠ 그래서 쿼 티 를 씁니다 ㅠ',
#  '꺼져',
#  '옵 빤 유 플 스타일',
#  '그냥 브랜드 차이 지요',
#  '제우스 면 신 보다 높 ㄴ 요 ㅋ',
#  '아이폰 유저 라 좋 은 일 하 시 네요',
#  '여친 이 sk 옴니아 2 쓰 다가 Sk 갤 투 로 유심 기변 했 는데 메론 어떻게 쓰 나요',
#  '별 은 뭔 가여',
#  '옵 지 에 맞춰서 쓰 셨 으면 gk 는 충분 할 겁니다',
#  'G 마켓 중고 구매 사이트 에 7 5 만 에 넘겼 어요 삼성 의 가방 을 느꼈 죠',
#  'S 4 A 골드 블랙 이 디자인 면 에서 는 가장 나 은 것 같 아요 from CV',
#  '근데 다시 보 니까 설정 계정 및 동기 화 메뉴 에 보 니까 계정 설정 이 되 어 있 습니다',
#  '구글 나우 사용 안함 으로 해 보 셨 나요',
#  '아이폰 4 s 쓰 던데요 ㅋㅋ 해밀턴 시계 차 고',
#  '헛 어 플로 도 해결 안 되 려나 ㅠㅠ',
#  '램 도 3 GB 맞 는 건가요',
#  '요거 1 0 0 입니다 ㅋ 갤 노트 3 9 만 원 에 풀렸 다니까 \\ 뭐 그리 비싸 울 집 앞 은 공짠데 \\',
#  '그렇 다면 차라리 허 그 유 같이 전신 이 보호 필름 인 제품 이 나 을 겁니다',
#  '갤 4 가 1 7 은 아직 아니 겠 죠 ＊',
#  '저 는 이만 퇴근 합니다 뿅',
#  '근데 5 4 무제한 돌릴 꺼 면 할인 받 는 게 좋 으니 낫 지 않 나요 ㅋㅋ 중고 는 할인 안 되 자 나 요',
#  '상황 을 보아하니 폭탄 돌리 기 맞 는 거 같 습니다 불량 글 이 이마이 넘쳐나 는 건 헬 투 스머프 이후 로 처음 인 거 같 네요',
#  '프로 업데이트 해 주 는 군요',
#  'Revolution reliabe real 랍니다 혁명 믿 을 수 있 는 실 제의',
#  '삼성 보 면 무료 액정 교체 은근 많 더라구요 ㅋㅋ 말 잘 하 면',
#  '중고 보단 새 거 죠 ㅎㅎ',
#  '이자르 도 대박 이 군요 ㅋ',
#  '6 월 1 일 변경 가능 이 죠 ㅋ',
#  '아하 ㅋ 하 긴 하 는군요 ㅋㅋ 본 적 이 없 어 서용 ㅋㅋ ㅋㅋ',
#  '아 아버지 어머니 두 분 다 겔 투 를 사용 하 시 네요 못난 아들놈 효 도 한 번 도와 주 세요',
#  '삼성 의 실수 였 지요 당시 에 는 ㅋ',
#  '화이트 핑크 가 은근히 어울리 는 조합 이 긴 하 군요',
#  '게시판 에 글 보 니깐 카메라 화질 도 괜찮 던데',
#  'ㅎㅎ 보내 드릴게요 쪽지 주세요',
#  '테이크 와 미라크 사이 에서 고민 중 입니다 구원 해 주 세요',
#  '술 많이 먹 고 피곤 할 때 수영 하 면',
#  '갤럭시 탭 중국 산 배터리 당첨 되 었 네요',
#  '네모나 고 모서리 가 둥근 데 요',
#  '왜 그럴까요 전 여기 서 왕따 ㅜㅜ',
#  '일본 판 갤럭시 J 랑 네이밍 이 같 으면 CLiOS',
#  '저 도 옵 뷰 2 보드 교체 했었 는데 맥주 소 가 같 더라구요 ＊',
#  '9 월 마지막 에 r 3 랑 베 넘 식 이 타 버렸 는데 유물 전 만 하 니 다행 이 네요',
#  '제 폰 이 베 가레 이 서 1 인데 단통 법 때문 에 버티 고 있 네요',
#  '클린 콜 한번 사용 해 볼게요 감사 합니다',
#  '공감 합니다 그 당시 광고 는 아이폰 을 아주 쉽 게 능가 하 는 제품 이 었 어요',
#  '실사 면 요 자 는 별로 아닌가요',
#  '헐 휴업 에 베가 s 요 자 이거 타 야 데 는 건가 ㅎ ㄷ ㄷ ㄷ',
#  '기기 를 멜론 측 에 등록 하 시 면 될 거 에요 제조 일자 부분 은 공장 한 번 들어갔 다 왔 다고 생각 하 시 면 편할 듯',
#  '될 텐데요 행 아웃 깔 수 있 을 겁니다 ＊',
#  '베가 S 올무 에 사은품 까지 풀렸 네요 ㅎㅎ',
#  '신 청요',
#  '제 가 선착순 안 에 는 들어간 것 같 거든요 이후 에 도 2 번 이나 재 판매 했 구요 원래 펑 은 소식 이 없 는 거 군요',
#  '뽐 기운 정말 없 으시 네요 안타까움 요',
#  '사실 커플 폰 할려고 여친 이랑 한 건데 여친 만 개통 되 서 더욱 심난 하 네요 ㅠㅠ',
#  '최소 3 만 원 만 잡히 면 별로 얼마 든지 결제 할 수 있 다는 거 아닌가요',
#  '아 정말 수고 가 많 으십니다 통화 가 안 되 니 너무 답답 하 네요',
#  '젤리빈 은 os 자체 가 별로 인 것 같 아요 진저 에서 가장 큰 발전 이 라 느꼈 던 거 같 네요',
#  '둥글둥글 갤 스 시리즈 같 은 느낌',
#  '3 5 때문 에 시리우스 에 는 별 감흥 이 없 지만 베 가 라면 글 램 에서 바로 갈 아 탑 니다 아 베가 디자인 이쁘 더라고요',
#  '사장 님 랜드 스 피더 한 대 나눔 해 주 세요 8 5 6',
#  '이번 디자인 은 좀',
#  '로이 는 8 0 0 만 화소 라는 데 안습 이 네요',
#  '아이패드 1 6 g 3 g 쿨 매 3 5 까지 나오 던데요 좀 아쉽 네요 ㅋ',
#  'S 3 는 괜히 껴서 안습 ㅋ 애당초 연식 차 가 크 니 어쩔 수 없 나 베 요',
#  '휴 포 에선 r 3 하지만 지금 쓰 고 있 는 폰 은 옵 쥐 @@',
#  '전 충전 은 아니 지만 차 에 블루투스 로 스트리밍 해서 듣 는 덱 끊겨 요',
#  '그러 게 요 ㅎ',
#  '사람 은 적응 하 는 동물 이 라 노트 도 별로 안 클 꺼 같 군요',
#  '미라크 옵 원 시크 할부금',
#  '사 죠 남친 님',
#  '갤럭시 노트 S 펜 으로 그려 본 추억 의 태권 브이',
#  '분명히 교환 신청 거부 봤 을 텐데 그래서 거부 했 습니다 어차피 팔 아서 교환 도 못 합니다 ㅋㅋ',
#  '몇 일전 부터 대놓고 업체 이름 까지 나돌 았었 어요',
#  '아무래도 베 터리 문제 겠 죠 from CV',
#  '음 이건 좀 아닐 꺼 같 다는 개인 적 인 생각',
#  '정말 인가요 갤 스 하관 이 길 지만 1 6 9 의 4 3 인치 액정 때문 에 더 길수 도',
#  '동감 앵그리 버드 ㅠ ㅠ',
#  'ㅋㅋㅋ ㅋㅋㅋ ㅋㅋ 여깄어요 ㅋㅋ 베레기 로 3 년 버텼 음 돠',
#  '무슨 놈 의 베 터리 가 반나절 에 절반 을 다 냐',
#  '갤럭시 s 3 가격 많이 떨어졌 네요 ㅠㅠ',
#  '취소 당하 는 거 라서 귀찮 음 ㅜㅜ',
#  '제일 쎈 놈 으로 사 시 면 되 요',
#  '어쨌든 저쨌 든 아몰레드 로 욕먹 는 삼성 이 상품 의 개선 을 위해 끊임없이 노력 하 는 모습 에 박수 를 보낸다',
#  'ㅡㅡ 그러 지 마셔요 다른 의견 먹 을까 두렵 습니다',
#  '으아 진짜 자주 떨구 는데 큰일 입니다 ㅜㅜ',
#  'ㅋㅋ 예전 에 전설 의 가격 한 번 보 고 나 서부터 현재 가격 이 너무 비싸 다는 인식 ㅇ ㅣ 강해서 잘 안 탑 니 다',
#  '내일 옴니아 2 가지 게 되 요',
#  '뒤 면 각 진 디자인 은 느껴 지 는 건가 여 아님 그냥 무늬',
#  'nokia tune 도 재밌 어요 over the horizon 은 요새 나왔 지만 피처 폰 시절 부터 벨 소리 로 컨셉 잡 은 친구 들',
#  '멜론 프리 티켓 망했 어요 ㅋㅋ 제 가 개념 없이 번이 를 ㅠㅜ',
#  '국내 에서 통신사 를 통해서 판매 하 는 스마트폰 중 에 6 만 한 물건 은 없 더군요',
#  '베가 LTE A 님 소환 요새 흔히 빵 티아 라고 하 는 별도 얹 어 준다',
#  '3 g 모델 은 sk 전용 으로 lte 보다 먼저 출시 됬 었 죠',
#  '4 7 인 친데 가상 버튼 과 테스 크 바 땜 에 4 3 정도 로 보입니다 ㄷ ㄷ',
#  '좌표 좀 부탁 드립니다 ㅠ ㅜ',
#  '감사 합니다 이번 엔 대리점 에서 살짝 말투 가 바뀌 던데 제발 양품 왔 으면 좋 겠 네요 ㅎㅎ',
#  '저 랑 비슷 하 시 네요 ㅋㅋ 저 도 시리우스 만 기다리 면서 계속 새로 고침 이러 다가 갑자기 훅 나왔 다 사리 질지 도 모른다는 불안 감 ㅠㅠ',
#  '번인 이 좋아합니다',
#  '갤럭시 노트 를 노트북 이 라고 보 시 는 독특 한 시각 을 가지 셨 군요 ㅎ',
#  '전 1 년 반 정도',
#  '랩 십 랜드 가 야지',
#  '애플 스토어 들어오 기 전 까지 iOS 를 떠나 겠 습니다',
#  '베가 가 힘 을 좀 냈으면',
#  '7 0 8 0 정도 되 겎네요',
#  '갤럭시 S 2 만큼 스 팩 깡패 가 아니 니 실망 도 큰 듯',
#  '2 4 0 0 0 랑 9 9 0 0 은 왜 붙 는 건가요',
#  'ㅇㅇ 골드 블랙 이쁜 거 같 아요',
#  'KT 갤럭시 S 2 예판 내일 까지 3 0 차수 까지 발송',
#  '이것 도 아주 오래 된 고전 루머 중 하나 죠',
#  '누군가 2 0 만 원 에 사 가 겠 군요 ㅎㅎㅎ ㅎㅎ',
#  '이런 광고 도 앞 으로 몇 년 이나 더 만들 수 있 을지',
#  '갤 스와 는 상관 없 지만 대리운전 하 면 왜 한 화면 을 오래 쓰 나요 되게 궁금 하 다',
#  '노바 쓰 면 어느 정도 는 상관없 는 문제 네요 삼성 페이 는 좋 아 보여요 from CV',
#  '아스팔트 8 처럼 최신 3 D 만 아니 면 되 죠 ㅎㅎ from CV',
#  '베레기 2 갖 고 있 는데요 레알 쓰레기 입니다 ㅋㅋㅋ 그냥 장난감 으로 갖 고 있 는 거 지 실사 로 는 절대 못 써요',
#  '그냥 설정 휴대폰 정보 배터리 부분 보 면 나와요',
#  '둘 다 좋 은 폰 이 에요 주머니 에 넣 고 쓰 실려면 갤 알 큰 거 쓰 시 고 싶 음 갤 놋',
#  '베가 는 3 5 단자 있 나요 시리우스 는 스마트폰 이 랍시고 통합 2 0 핀 을 집어넣 는 위엄 을 ㅋ',
#  '참 삼성 마크 로 바꾸 길 잘 했 어 Anycall 보다 훨씬 낫 네',
#  '뽐뿌 를 안 하 는 사람 은 있 어도 한 번 만 해 본 사람 이 요 깃 넹 응',
#  '정말 최강 이 죠 제 생각 이 지만 수요 도 많 고 아이폰 보다 더 낫 다고 생각 합니다',
#  '디테일 하 시 네요 담 번 엔 추가 해 보 겠 습니다',
#  '저 레이더 인데 안 되 는 어 플 없 던데 진짜 안 되 는 게 있 나 여 게임 은 모르 겠 네요 안 해서 ㅋ',
#  '내일 송파역 오 시 면 드릴게요',
#  '3 개월 내 로 번인 생기 면 공짜 로 수리 받 으면 되 지요 1 년 이 내 라고 본인 이 명시 해 놨잖아요 글 에 ㅎ',
#  '사실 저 미친 듯 한 켜 짐 만 잡 아도 대기 시간 이 2 배 는 늘어날 것 같 아요',
#  '1 년 사용 하 실 분 이 라면 1 2 1 0 0 만 원 도 괜찮 은 조건 이 죠',
#  '대출 받 아서 레고 살까',
#  'ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ ㅋㅋㅋ 왜 그러 세요',
#  '느 헝 그렇 군요 그냥 내일 하나 사 야 겠 네요',
#  '라이트 유저 에겐 가혹 한 요금제 아닌가요 ㅋ',
#  '갤럭시 S 를 팔 았 는데요 구매자 가 입금 후 잠적 했',
#  '아니 어떻게 저걸 그렇게 생각 하 실까요 ㅋㅋ ㅋㅋ',
#  'ㅋㅋ 베가 s 상당히 빠르 고 괜찮 죠 아이폰 에 견줄 만 한 듯',
#  '핑크 크리 때문 에 못 탈 거 같 아요 ㅠㅠ',
#  '지스리 누렇 네요',
#  '하긴 1 0 면 확 느껴 지지 는 않 겟 죠 ㅋ',
#  '스카이 고객 센터 연결 해서 물 어 봤 어요 ㅎㅎ',
#  '넵 충무로 요 갔 더니 무지 친절 하 게 잘 해 주 시 더라구요',
#  'mvno 타세 요',
#  '저 도 알락 티케 신청서 재작 성 문자 와서 탔 는데 ㅠㅠ 양품 이 젭 알',
#  '갤럭시 S 갤럭시 S 2 벨 소리 문자 알림 음 알람 소리 입니다 모든 파일 모음',
#  '일본 판 갤 스 는 갤 스 2 말 고 1 0 8 0 p 까지 돌린다고 하 잖아요 ㄷ',
#  '베가 레이서 가 먼저 겠 죠 사용 자 가 더 많 으니깐 요',
#  '감사 합니다 2 번 줄서 겠 습니다',
#  'xda 에서 트윅 이 나왔 어요',
#  '하반기 정도 되 서 가격 좀 떨어지 면 가 성비 적 으로 도 아주 끝내 줄 거 같 습니다',
#  '그러 게 여',
#  '시리우스 ㅜ ㅜ 제 가 지금껏 써 본 맛 폰 중 에 제일 맘 에 들었었는데 ㅠㅠ',
#  '저 도 제겐 이 놋 투 가 분 에 넘치 는 폰 이 네요',
#  '이 돈 주 고 뭐 하 러 이거 사 냐',
#  '스크린 구라 베젤 이 너무 부각 되게 나오 네요',
#  '추운 곳 에서 있 으면 액정 에 이상 현상 이',
#  '저 도 그다지 안 떙기네요',
#  '갤 투 겠 죠',
#  '겹쳐 가 뭔가요 그리고 어떤 점 이 아니 라는 건지 요 ＊',
#  '너 도 옴 레 기지 하 는 동족 의식 느끼 려고 했 다가 패망 의식 느끼 고 가 셨 을 듯 ㅋㅋㅋ ㅋㅋ',
#  '몰라요 나 도',
#  '그렇 다면 패스 하 시 면 됩니다',
#  '아 그런가요 ㅜㅜ 그래도 그냥저냥 써야 줘 모 ㅜㅜ',
#  '플 래쉬 는 사진 찍 는 곳 에서 메뉴 눌러서 찾아보 면 번개 모양 같 은 거 나옵니다 그 중 에 선택 하 면 되 요 ㅋ',
#  '갤럭시 S 3 해 외판 개봉 샷 미국 3 G 주파수 정보 포함',
#  '와인 디피 까 셨 네요 ㅋ',
#  '살짝 닿 는 순간 뜨 는 느낌 이 에요',
#  '당첨 이 요 쪽지 로 주소 랑 연락처 주세요 저거 전부 다 보내 드립니다 주변 에 나눠 주 세요 ㅋ',
#  '헬 통 의 힘 을 기대 해 봅니다',
#  '그냥 제 돈 주 고 쓰 기 에 는 조금 부족 한 친구 죠 ㅎㅎ',
#  '전 나올 거 같 은데요 댓글 들 이 이상 한 듯',
#  '친구 가 옵티머스 2 x 를 대리점 에서 사 왔 는데',
#  '흠 G 5 0 이 갤 플 인가요 G 5 0 이 왠지 갤 아 처럼 될 꺼 같 아서 불안 불안 하 네요 ㅠ ㅠ',
#  '영상 보 니 멋지 네요 디자인 은 갤 넥 스럽 다고 생각 했 는데 보 다 보 니 멋진 듯 ㅎ',
#  '어쨋든 기기 값 은 다 내게 된다는 거 죠 뭐',
#  '진정 잘 탔 다고 생각 되 는 옵티머스 lte 2',
#  '저 는 이어폰 때문 이 라도 넥 원사 요 ㅎㅎ',
#  '근데 삼성 휴대폰 비싸 게 팔 면 삼성 도 많이 떨어지 나요 통신사 만 그냥 처묵 처묵 하나 요 이름 이 진짜 사람 홀리 기 딱 좋 네요 갤럭시 에이스',
#  'mx 플레이어 가 갑 인 것 같 아요',
#  '수명 을 줄일 정도 는 아닐 겁니다 모니터 나 티비 전자 렌지 보다 적 을 껍니다',
#  '그래도 있 으면 좋 겠 네요',
#  '헬스 장 에서 발견 한 평범 하 지 않 은 폰',
#  '괜찮 습니다 걱정 하 실 것 없 다고 잘 설득 시켜 드리 세요',
#  'lte 면 스냅 인가요',
#  '터치 감 은 오히려 옵 2 2 보단 좋 은 것 같 습니다 웅웅 하 는 진동 세기 가 저 에게 는 더 마음 에 드 네요',
#  '반올림 이 라 크기 차이 가 좀 나 는 군요',
#  '르 그 는 역시 가격 하락 의 선봉장',
#  '근거 가 있 으시 나요',
#  '심각 하 군요',
#  '아 별 내 가 받 고 요금 은 부모 님 이 내 는데 자꾸 야근 생각 만 하 고 빨리 디파이 가 나와야 정신 차릴 껀 데',
#  '이미 단종 선언 한 걸로 알 고 있 는데 용',
#  '해 외판 ㅎ',
#  '옵티머스 2 X 사면 하나 더 준다',
#  '액정 이 금 갔 잖아요',
#  'http itempage 3 auction co kr DetailView aspx ItemNo A 5 4 7 3 8 4 4 5 1 listqs keyword 3 d 2 6',
#  '기본 키보드 에서 한 자키 를 못 찾 겠 습니다 한 자키 가 나오 도록 하 는 방법 을 알려 주 세요 from CLiOS',
#  '옵티머스 2 x 2 0 1 5 년 활용 기',
#  '화질 이 안타까운 건 처음 이 군요 ㅠㅜ',
#  '베 가레 이 서 아 샌 다 좋 은데',
#  '유진 투자 증권 에서 갤럭시 S 2 이벤트 하 는 거 요',
#  '와 느낌 있 네요',
#  'sk 사용 중 인데 착 기 가 착하 지 않 고 가족 들 이 저 빼 고 U 사용 중 이 라 넘어갈까 고민 중 이 에요',
#  '접수 번호 면 창 을 먼저 열 어 놓 는 게 우선 이 군요',
#  '빨리빨리 사 라는 수작 일 뿐 광고 이 니 더기 다립 시 다 저 는 갤 탭 갤 투 조합 ㅎ 쓸 예정 이 라서 아직 급하 지 않 아요',
#  '괜찮 아 디파이 니까 ㅋ 디파이 하나 주문 하 러 가 야 겠 NEO ㅋㅋㅋ',
#  '아이폰 이 sk 도 나오 니 이제 뭐 kt 에 안 풀 이유 가 없 죠 그렇 다고 LG 에 독점 공급 은 좀 아니 니',
#  '헉 그런 가요 액정 조 차 도 호환 이 안 된다니 ㅜㅜ',
#  '기변 은 좀 비싸 더군요 7 8 이 였 습니다',
#  '메탈 메탈 메탈 Hang The CEO Help This Company',
#  '헐 전 화이트 케 갈 할까 생각 중 이 었 는데 ㅅ',
#  '감사 합니다 더 찾 아 볼게요 플레오 멕스 랑 쿨 케이스 도 알아볼 게 용',
#  '환영 합니다 ㅋ from CLiOS',
#  '전 옵 니아 2 요 모토 로 이 는 있 어서',
#  '주위 에 친구 의 도움 을',
#  '넵 LTE 로 받 았 습니다 그러나 이런 경우 에 피해 보 는 거 감수 하 라는 법 도 없 잖아요',
#  '켁 ㅎ ㄷ ㄷ ㄷ ㄷ',
#  '참 을 수 밖 에 없 었 습니다 1 7 이 뭔지 ㅜ ㅜ 어쨌든 감사 합니다',
#  '오늘 회사 사람 이 샀 는데 정말 좋 아 보이 더라구요',
#  '허 이 양반 사랑 을 좀 아 시 는 낭만파 시네',
#  '넥서스 5 에 갤럭시 번들 이어폰 사용 가능 한가요',
#  '갤럭시 s 2 잠깐 만져 봤 습니다 터치 감 거의 아이폰 을 따라왔 네요',
#  '아 ㅠ 눈 에서 물 이 나와 여',
#  '그렇 군요 ㅎㅎ',
#  '지하철역 근처 땅값 이 비싸 죠 그런 건 역세권 헬 지 가 잘 터지 는 곳 은 헬 세권',
#  '5 못 기다린다면 갤 3 강추 제 와이프 는 넘 어 갑니다',
#  '실제론 여전히 아이폰 4 가 느려요 아이폰 4 s 는 갤럭시 2 와 비슷 하 거나 조금 빠르 구요',
#  '디자인 정말 충격 이 던데 아니 길 바랍니다 ㅋㅋ',
#  '1 2 1 1 최고 의 장점 ㅎㅎ',
#  '화이트 는 크롬 부분 때문 에 맘 에 안 듬',
#  '갤 3 lte 젤리빈 으로 업 뎃하니까 대각선 드래그 잘 됩니다',
#  '그만큼 대국민 사기극 이 었 으니까 뭐 그 당시 에 안 당해 본 사람 이 면 알 수 가 없 는 거 니 ㅎㅎ',
#  '새해 기념 투표 율 7 7 달 성 나눔 못했 던 옴니아 2 멜 폰 폰 나눔 합니다',
#  'ㅋㅋㅋ 역시 화이트',
#  '1 얼마 전 에 는 ㄱ 걸로 테러 예방 했 다며 자랑 까지 하 던 나라 인데 ㄷ ㄷ ㄷ',
#  '네 오로지 3 d 만 보 면 타실 만 해요 그 이상 기대 하 진 마세요',
#  '에 효 원래 라면 요 자 올무 할 부 1 3 정도 로 나왔 어야 하 는 기 긴데 요즘 이 빙하기 라',
#  '옵티머스 LTE 2 젤리 빈 문제점 이 뭐 있 을까요',
#  '흠 장갑 같 은 경우 는 터치 가 되 는 장갑 을 쓰 시 면 될 것 같 습니다 요새 그런 장갑 많 잖아요',
#  '저번 에 걸렸 으면서 또 이러 네 참나 항상 걸릴 거 면서 왜 그러 는지 참',
#  '화이트 는 아니 죠 컥 눙물이 앞 을 ㅜ',
#  '갤 3 배터리 커버 센터 가 면 얼마나 하 나요',
#  '하지만 이미 회선 은 으악 ㅠㅠ좌표는 휴업 이 요 아 진짜 달리 고 싶 네요 5 5 요금제 를 써도 4 만 원 이 안 된다는 ㄷ ㄷ ㄷ',
#  '얼마 에 구매 하 셨 어요 저 도 베레 지금 구매 대기 중 이 라서요',
#  '스마트폰 은 더 주 는 걸로 압 니다',
#  '전 집 에 가 서 애 들 이랑 저녁 먹 을래요',
#  '베가 S 의 생명 연장 의 꿈 은 이렇게 사라졌 군요 ㅠㅠ',
#  '베가 레이서 라도 걸리 믄 대박 이 죠',
#  '키보드 버그 가 사람 미 춰 버리 게 합니다 타자 치 는 감도 쉣 이 고 ㅜ ㅜ',
#  '그렇 죠 공기 계 구매 후 기변 이 면 안 붙 는 게 당연 한데 제 케이스 는 어떤지 모르 겠 네요 ㅠ',
#  '옴니아 2 배송 왔 어요 ㅎㅎ',
#  '서울대 공대 대학원생 이 만들 었 겠 네요',
#  '일 처리 참 빨라서 님 도 오늘 받 으실 듯 하 네요 사이드 터치 보정 은 어 케 해야 되 는지 참 남감 하 네요',
#  '옵티머스 LTE 2',
#  '1 2 1 2 로 탄 거 정말 효도 폰 입니다 ㅎㅎ',
#  '아 앙 대',
#  '1 8 주파수 2 G 사용 자 들 이 있 는데요 이미 그거 말 고 도 8 0 0 MHZ 대역 확보 하 고 있 어요 lte 가능 해요',
#  '이이 도 바로 찍힙니다',
#  '3 0 일 후 에 준대요 홈페이지 보 세요',
#  '옵티머스 를 단숨에 밟 을 놈 이 나오 겠 져 삼성 이 니까',
#  '갤럭시 S 2 루팅 커널 올리 신 분 들 초기 화 팁',
#  '갤 3 페블블루는 sgp 커브 드 크리스탈 엘 라고 슬림 핏 진 인디고 가 진리 화이트 는 뭐 든 잘 어울림',
#  '대충 봤 더만 홍철 하하 편 보고 팬 이 됬 다고 하 는 줄 알 았 네요 우와 대박 프라이드',
#  'SkT 사용 잔데 어제 밤 에 롤리팝 으로 업 글 했 는데 이런 문제 가 있 었 군요 ㅜㅜ',
#  '이런 말 좀 그렇 지만 개소리 네요',
#  '효도 하 고 용돈 생기 고 좋 은데요 근데 사은품 펑 하 면 난리나 겠 습니다 ㅠ ㅠ',
#  '언젠가 는 되 겄 지요 ㅎㅎㅎ',
#  '베가 레이서 3 이 베 갈삼 입니다요',
#  '후미 미라크 슬슬 사 야 겠 어요',
#  '진짠 가요 ㄷ ㄷ 그냥 태블릿 인 듯',
#  '시력 이 현미 경급 인 분 들 이 왜 이렇게 많 은지',
#  '핼 지 베가 레이서 하 고 베 각 플러스 하 고 얼마 차이 없 군요',
#  '으흐흐흐 속상 합니다 지금 주소록 백업 되 나 보 는데 ㅎㅎ ㅎㅎ 기 가 막히 네여 다 안 나와 여',
#  '사진 만 보 면 블랙 압승',
#  '아몰레드 다른 제품 도 많이 볼 수 있 으면 좋 겠 습니다',
#  '지존 이 다',
#  '저 도 못 받 았 는데요',
#  '논란 을 일부러 원한다 그분 의 행위 엔 범인 이 모르 는 깊 은 뜻 이 있 다는 건지 요즘 엔 삼성 도 종교 가 되 었 나 봅니다',
#  '어서 오 세요',
#  '흠 휴업 에 KT 갤럭시 탭',
#  '이쁘 네요 ㅇㅇ',
#  '타 타키 ㅠㅠ 사촌 동생 지못미',
#  '월 요금 십 만 원 크리',
#  '전 나올 거 라고 믿 어요 ㅜㅜ 완전 탐 남 ㅋㅋㅋ 화이트 완전 아',
#  '출시 물량 을 줄여 버렸 거나',
#  '맞 아요 배터리 커버 분리 안 되 는 범퍼 라 약간 불편 하 더라구요',
#  '진짜 너무 하네 추천 드립니다',
#  '엥 이게 영어 라구요',
#  '일단 순정 에서 통화중 녹음 은 지원 하 지 않 고 더 콜스 팸 은 제 가 사용 하 지 않 아서 잘 모르 겠 습니다 ㅠㅠ',
#  '그냥 가만히 있 는 게 좋 아요 ㅎㅎ 그리고 대란 에 탑승 해서 좋 은 폰 을 뙇 보여 주 면 승자',
#  '감사 합니다 □',
#  '네 흰색 이 요 근데 skt 껀 데 없 다고 kt 꺼 주 더군요 ㅋㅋ',
#  '맞대결 이 흥미 롭 게 벌어지 겠 군요',
#  '해 봤 는데 ㅋㅋ 갤 투 가 졌 어요 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ 제 갤 투 가 졌 기 때문 에 안 올려요 ㅋ',
#  '고민 할꺼 없이 겔 투 실사 한다면 요',
#  '중간 에 고추장 컬러 만 빼 면 다 괜찮 네요',
#  '3 G 쓰 실려면 설정 에서 LTE 만 비활성 하 시 면 되 실 듯 하 네요 저 도 그렇 게 하 고 쓰 고 있 어서',
#  '아래 도 올렸 던 글 이 지만',
#  '아 걍 지금 시리우스 질러야 겟 네요 ㅋㅋㅋ ㅋㅋㅋ',
#  '베가 레이서 구매 했 는데',
#  'lg 가 잘 만드 는 거 면 삼성 폰 써 보 시 면 기절 할 듯',
#  '아닙니다 다른 회사 들 이 미래 의 애플 을 카피캣 한 겁니다',
#  '이거 머 가 어떻게 돌아가 는 건지 ㅋㅋ 타 야 하나 말 아야 하나 ㅋ',
#  '서로 비교 될 대상 이 아니 여요 갤 그 는 그나마 갤럭시 시리즈 셔 비교 하 려면 팝 을 해야 될 껀 데',
#  '아이폰 5 s 느려 터져서 짜증 이',
#  '갤럭시 S TAB 베가 법인 물량 정보',
#  '같 은 값 이 면 당연히 아이폰 하 지만 아이폰 가격 이 면 아예 폰 을 안 사 요 ㅋㅋ ㅋㅋ',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(vocabulary=vocab,
                             binary=True, 
                             ngram_range=(1, 1), 
                             tokenizer=lambda x: x.strip().split())

# %%
dtm = vectorizer.fit_transform(corpus).toarray()
word_counts_per_doc = np.sum(dtm, axis=1)
result = np.dot(dtm, weight_matrix.T)

# %%
word_counts_per_doc
# Out:
# array([ 4, 19,  9, ..., 19,  4, 16], dtype=int64)

# %%
word_counts_per_doc ** 0.6
# Out:
# array([2.29739671, 5.85129724, 3.73719282, ..., 5.85129724, 2.29739671,
#        5.27803164])

# %% [markdown]
# ## 최종 결과물 도출

# %%
for func_idx, func in enumerate(functions):
    print("##### " + func)
    scores = - result[:, func_idx] / (word_counts_per_doc ** 0.6)
    for sent_idx in scores.argsort()[:10]:
        print(corpus[sent_idx].strip(), - scores[sent_idx])
    print("\n")
# Out:
# ##### 배터리
# 갠 적 으로 액정 필름 외 엔 케이스 를 안 끼우 는 스타일 이 라 ㅠㅠ 그냥 배터리 뒷 커버 만 하이퍼 스킨 이거 안 파나 요 ㅠㅠ 1.5920379858498444
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.5868812043625475
# 제 갤 삼 도 일 년 정도 쓰 니깐 배터리 부풀 더라구요 밧데리 케이스 가 안 닫힐 정도 에 요 as 는 안 되 더라구요 ㅜㅜ ＊ 1.581852421014835
# 한국 놋 투도 됩니다 배터리 커버 빼 면 단자 가 있 습니다 무선 충전 코일 모듈 이랑 충전기 사면 가능 합니다 1.5654875075226697
# SKT KT 모델 은 배터리 가 빨리 떨어진다고 합니다 배터리 시간 은 U 단말기 가 오래간다 네요 차이 가 많 나 더라구요 검색 하 시 면 원인 도 나올 겁니다 1.5455396098601166
# 본체 1 배터리 1 만 있 어서 배터리 걱정 이 네요 그냥 녹 네요 녹 아 ㅠㅠ 저장 도 문제 고 가볍 게 사용 하 기 딱 좋 네요 ㅎㅎ 1.5271367248541765
# s 2 실사 2 년 인데 아직 까지 큰 문제 없이 잘 쓰 고 있 습니다 배터리 문제 빼 곤 하 지만 이번 KT 옵 G 로 넘어갔 어요 1.5230331339103562
# 네 넹 베 가레 이 서 젤 첨 에 나와서 이병헌 이 타이어 굴리 는 CF 찍 고 갤 S 2 랑 경쟁 했 던 그 베가 레이서 요 ㅋ 1.5143288403000201
# 전 플립 커버 로 밑 에 받치 고 쓰 다 보 니 발열 은 잘 못 느꼈 는데 ㅜ 지금 보 니 저 도 4 4 도 네요 ㅡㅡ 1.5091554676695143
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.500810793647693
#
#
# ##### 촬영
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.6260105396273905
# 좋 던데요 3 D 샘플 영상 도 사진 동영상 직접 촬영 한 것 도 볼 만 합니다 아주 좋 아요 1.6112477243558267
# 전 아 트릭스 만족 하 면 쓰 고 있 어요 사무실 에서 멀 독 에 키보드 마우스 모니터 연결 해서 인터넷 게임 카톡 전화 노래 등등 좋 아요 ㅎㅎ 1.5909733990299102
# 아이폰 4 와 가로길이 가 사진 상 으론 비슷 해 보여서 비교 좀 부탁드릴께요 ㅠㅠㅠㅠ 가로 가 엄청 짧 고 세로 만 긴 기형 같 아서 고민 이 네요 ㅠㅠ 1.5619729497926584
# 뮤직 플레이어 재생 목록 설정 해 두 면 얼마 안가 목록 이 싹 사라지 는데 외장 메모리 에 노래 가 있 어서 인가요 혹시 해결 방법 있 는지요 1.5118096900706777
# 삼성 공돌이 들 의 염원 이 담긴 엑시노스 A 7 이나 A 5 나 사용 된 칩셋 의 원 소스 는 동일 한데 벤치 보 면 은근 벌어지 는 군요 1.5097632300022434
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.5091633797118267
# 플 래쉬 는 사진 찍 는 곳 에서 메뉴 눌러서 찾아보 면 번개 모양 같 은 거 나옵니다 그 중 에 선택 하 면 되 요 ㅋ 1.5066781934284283
# 네 넹 베 가레 이 서 젤 첨 에 나와서 이병헌 이 타이어 굴리 는 CF 찍 고 갤 S 2 랑 경쟁 했 던 그 베가 레이서 요 ㅋ 1.4995165147950222
# 실물 아이폰 노트 당장 에 세 개 를 비교 하 면 원본 색 에서 가장 먼 게 노트 입니다 색재 현 율 까지 갈 것 도 없 고요 1.4906936018679287
#
#
# ##### 디자인
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.5920661869506452
# 하긴 광고 도 참 동화 적 이 고 정적 이 라서 요란 한 녀석 들 에게 묻히 는 경향 도 있 는 거 같 아요 마케팅 시대 라 역시 1.5460314642296782
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.497346736636599
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.4956949088086593
# 디자인 은 개인 취향 이 죠 어떨 땐 넥스 그립 감 이나 디자인 이 좋 고 어떨 땐 갤 스 의 물리 버튼 이 또 너무 맘 에 들 고 1.4667396098894052
# 논란 을 일부러 원한다 그분 의 행위 엔 범인 이 모르 는 깊 은 뜻 이 있 다는 건지 요즘 엔 삼성 도 종교 가 되 었 나 봅니다 1.449410032676788
# 네 넹 베 가레 이 서 젤 첨 에 나와서 이병헌 이 타이어 굴리 는 CF 찍 고 갤 S 2 랑 경쟁 했 던 그 베가 레이서 요 ㅋ 1.446185530331715
# 빨리빨리 사 라는 수작 일 뿐 광고 이 니 더기 다립 시 다 저 는 갤 탭 갤 투 조합 ㅎ 쓸 예정 이 라서 아직 급하 지 않 아요 1.4421674074970552
# 해상도 자체 가 다르 고 가격 포지션 도 다릅니다 A 는 펜 이 있 다는 거 제외 하 면 사실 쓸 만 한 구석 이 없 죠 CLiOS 1.4396502303910477
# 갠 적 으로 액정 필름 외 엔 케이스 를 안 끼우 는 스타일 이 라 ㅠㅠ 그냥 배터리 뒷 커버 만 하이퍼 스킨 이거 안 파나 요 ㅠㅠ 1.4343417855887208
#
#
# ##### 화면
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.6033348824421105
# 아이폰 4 와 가로길이 가 사진 상 으론 비슷 해 보여서 비교 좀 부탁드릴께요 ㅠㅠㅠㅠ 가로 가 엄청 짧 고 세로 만 긴 기형 같 아서 고민 이 네요 ㅠㅠ 1.6012189997355881
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.5737502370682084
# 전 아 트릭스 만족 하 면 쓰 고 있 어요 사무실 에서 멀 독 에 키보드 마우스 모니터 연결 해서 인터넷 게임 카톡 전화 노래 등등 좋 아요 ㅎㅎ 1.5434802061768715
# 저 도 갤 투 쓸 때 갤 투문 자음 은 빼 놨었 는데 길거리 에서 들려오 는 휘파람 소리 문자 음 이 너무 탐나 더라구요 ㅠ 1.5292815088880631
# 저 도 LED 는 그냥 포기 에 가까웠 는데 화면 누런 게 심해서 겸사겸사 교 품 했 네요 1.5017308062200425
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.4983307327368822
# 을 발견 했 습니다 전원 버튼 누르 면서 스카 이 로고 멀티 테스 킹 누르 면 스크린 샷 기능 되 네요 ㅋㅋ 신기 함 니더 1.495796851482476
# 밝 기 낮추 면 더 침침 해 지 는 느낌 이 들 어 항상 밝기 오 십 이상 으로 쓰 네요 다른 폰 들 도 밝 게 썼었 어요 1.4850135797817245
# 저 랑 비슷 하 시 네요 ㅋㅋ 저 도 시리우스 만 기다리 면서 계속 새로 고침 이러 다가 갑자기 훅 나왔 다 사리 질지 도 모른다는 불안 감 ㅠㅠ 1.4810289141311113
#
#
# ##### OS
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.556047841238661
# 삼성 공돌이 들 의 염원 이 담긴 엑시노스 A 7 이나 A 5 나 사용 된 칩셋 의 원 소스 는 동일 한데 벤치 보 면 은근 벌어지 는 군요 1.5184740007502473
# 하긴 지금 삼성 애플 두 기업 의 네임 밸류 가 지나치 게 높 다 보 니 시장 이 양극 화 되 는 문제 도 있 죠 ㅋㅋ 1.4793220078804372
# 논란 을 일부러 원한다 그분 의 행위 엔 범인 이 모르 는 깊 은 뜻 이 있 다는 건지 요즘 엔 삼성 도 종교 가 되 었 나 봅니다 1.4712560926479723
# aP 근소 한 차이 가 아닙니다 클럭 은 2 0 0 메 mhz 밖에 차이 가 안 나 지만 칩셋 자체 가 틀려요 ex 가 압도 적 입니다 1.4615308854040916
# 하긴 광고 도 참 동화 적 이 고 정적 이 라서 요란 한 녀석 들 에게 묻히 는 경향 도 있 는 거 같 아요 마케팅 시대 라 역시 1.4524966668126786
# 국내 언론 의 보도 와 는 완전히 상반 되 는 결과 네요 애플 망 한다던 글 많이 보이 던데 역시 국내 만 큰 거 찾 나 보 네요 1.444640168505235
# 헐 지금 쓰 고 있 는 폰 도 9 2 6 메가 인데 어떻게 차세대 삼성 을 대표 하 는 폰 의 램 이 7 8 0 메 가래 1.4443216618170953
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.442336370569377
# 이번 에 iPhone 5 를 구입 했 는데 전자파 가 많이 나온다 네요 정말로 많이 나옵니까 그렇 다면 저 는 다른 폰 으로 바꿀려구 요 ㅠㅠ 1.440216464503296
#
#
# ##### 색
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.5601853783051387
# 갠 적 으로 액정 필름 외 엔 케이스 를 안 끼우 는 스타일 이 라 ㅠㅠ 그냥 배터리 뒷 커버 만 하이퍼 스킨 이거 안 파나 요 ㅠㅠ 1.5376087318099863
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.5236414009707153
# 실물 아이폰 노트 당장 에 세 개 를 비교 하 면 원본 색 에서 가장 먼 게 노트 입니다 색재 현 율 까지 갈 것 도 없 고요 1.5059340709913716
# 하긴 광고 도 참 동화 적 이 고 정적 이 라서 요란 한 녀석 들 에게 묻히 는 경향 도 있 는 거 같 아요 마케팅 시대 라 역시 1.5011574108340084
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.4946230808449987
# 아이폰 4 와 가로길이 가 사진 상 으론 비슷 해 보여서 비교 좀 부탁드릴께요 ㅠㅠㅠㅠ 가로 가 엄청 짧 고 세로 만 긴 기형 같 아서 고민 이 네요 ㅠㅠ 1.482158320843853
# 논란 을 일부러 원한다 그분 의 행위 엔 범인 이 모르 는 깊 은 뜻 이 있 다는 건지 요즘 엔 삼성 도 종교 가 되 었 나 봅니다 1.4698734306244796
# 이름 을 멍이 라고 붙여서 그렇 지 멍 이 랑 은 다르 죠 카메라 렌즈 와 광원 에 대한 이해 가 없 으니 발생 하 는 일 이 라고 봅니다 1.453318970270306
# 갤럭시 탭 은 검정 색 이어폰 이 들 어 있 어서요 당연히 본체 색깔 따라가 는 줄 알 았 어요 1.4528779432891539
# c:\python37\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for func_idx, func in enumerate(functions):
    print("##### " + func)
    scores = - result[:, func_idx] / (word_counts_per_doc ** 0.6)
    i = 0
    for sent_idx in scores.argsort():
        if func not in corpus[sent_idx] and i < 10:
            print(corpus[sent_idx].strip(), - scores[sent_idx])
            i += 1
    print("\n")
# Out:
# ##### 배터리
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.5868812043625475
# 네 넹 베 가레 이 서 젤 첨 에 나와서 이병헌 이 타이어 굴리 는 CF 찍 고 갤 S 2 랑 경쟁 했 던 그 베가 레이서 요 ㅋ 1.5143288403000201
# 전 플립 커버 로 밑 에 받치 고 쓰 다 보 니 발열 은 잘 못 느꼈 는데 ㅜ 지금 보 니 저 도 4 4 도 네요 ㅡㅡ 1.5091554676695143
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.500810793647693
# 저 도 갤 투 쓸 때 갤 투문 자음 은 빼 놨었 는데 길거리 에서 들려오 는 휘파람 소리 문자 음 이 너무 탐나 더라구요 ㅠ 1.4764129553621304
# 국내 에 도 빨리 나오 면 좋 겠 네요 S 3 는 참 좋 은 폰 인데 이왕 2 GB 로 올리 지 1 5 GB 는 좀 아쉽 네요 1.4737448842902592
# 빨리빨리 사 라는 수작 일 뿐 광고 이 니 더기 다립 시 다 저 는 갤 탭 갤 투 조합 ㅎ 쓸 예정 이 라서 아직 급하 지 않 아요 1.4721076639125106
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.4677822092610677
# 아이폰 4 와 가로길이 가 사진 상 으론 비슷 해 보여서 비교 좀 부탁드릴께요 ㅠㅠㅠㅠ 가로 가 엄청 짧 고 세로 만 긴 기형 같 아서 고민 이 네요 ㅠㅠ 1.4672137424325604
# 저 랑 비슷 하 시 네요 ㅋㅋ 저 도 시리우스 만 기다리 면서 계속 새로 고침 이러 다가 갑자기 훅 나왔 다 사리 질지 도 모른다는 불안 감 ㅠㅠ 1.4640988142844484
#
#
# ##### 촬영
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.6260105396273905
# 전 아 트릭스 만족 하 면 쓰 고 있 어요 사무실 에서 멀 독 에 키보드 마우스 모니터 연결 해서 인터넷 게임 카톡 전화 노래 등등 좋 아요 ㅎㅎ 1.5909733990299102
# 아이폰 4 와 가로길이 가 사진 상 으론 비슷 해 보여서 비교 좀 부탁드릴께요 ㅠㅠㅠㅠ 가로 가 엄청 짧 고 세로 만 긴 기형 같 아서 고민 이 네요 ㅠㅠ 1.5619729497926584
# 뮤직 플레이어 재생 목록 설정 해 두 면 얼마 안가 목록 이 싹 사라지 는데 외장 메모리 에 노래 가 있 어서 인가요 혹시 해결 방법 있 는지요 1.5118096900706777
# 삼성 공돌이 들 의 염원 이 담긴 엑시노스 A 7 이나 A 5 나 사용 된 칩셋 의 원 소스 는 동일 한데 벤치 보 면 은근 벌어지 는 군요 1.5097632300022434
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.5091633797118267
# 플 래쉬 는 사진 찍 는 곳 에서 메뉴 눌러서 찾아보 면 번개 모양 같 은 거 나옵니다 그 중 에 선택 하 면 되 요 ㅋ 1.5066781934284283
# 네 넹 베 가레 이 서 젤 첨 에 나와서 이병헌 이 타이어 굴리 는 CF 찍 고 갤 S 2 랑 경쟁 했 던 그 베가 레이서 요 ㅋ 1.4995165147950222
# 실물 아이폰 노트 당장 에 세 개 를 비교 하 면 원본 색 에서 가장 먼 게 노트 입니다 색재 현 율 까지 갈 것 도 없 고요 1.4906936018679287
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.4865033176743434
#
#
# ##### 디자인
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.5920661869506452
# 하긴 광고 도 참 동화 적 이 고 정적 이 라서 요란 한 녀석 들 에게 묻히 는 경향 도 있 는 거 같 아요 마케팅 시대 라 역시 1.5460314642296782
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.497346736636599
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.4956949088086593
# 논란 을 일부러 원한다 그분 의 행위 엔 범인 이 모르 는 깊 은 뜻 이 있 다는 건지 요즘 엔 삼성 도 종교 가 되 었 나 봅니다 1.449410032676788
# 네 넹 베 가레 이 서 젤 첨 에 나와서 이병헌 이 타이어 굴리 는 CF 찍 고 갤 S 2 랑 경쟁 했 던 그 베가 레이서 요 ㅋ 1.446185530331715
# 빨리빨리 사 라는 수작 일 뿐 광고 이 니 더기 다립 시 다 저 는 갤 탭 갤 투 조합 ㅎ 쓸 예정 이 라서 아직 급하 지 않 아요 1.4421674074970552
# 해상도 자체 가 다르 고 가격 포지션 도 다릅니다 A 는 펜 이 있 다는 거 제외 하 면 사실 쓸 만 한 구석 이 없 죠 CLiOS 1.4396502303910477
# 갠 적 으로 액정 필름 외 엔 케이스 를 안 끼우 는 스타일 이 라 ㅠㅠ 그냥 배터리 뒷 커버 만 하이퍼 스킨 이거 안 파나 요 ㅠㅠ 1.4343417855887208
# 하긴 지금 삼성 애플 두 기업 의 네임 밸류 가 지나치 게 높 다 보 니 시장 이 양극 화 되 는 문제 도 있 죠 ㅋㅋ 1.422132362543369
#
#
# ##### 화면
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.6033348824421105
# 아이폰 4 와 가로길이 가 사진 상 으론 비슷 해 보여서 비교 좀 부탁드릴께요 ㅠㅠㅠㅠ 가로 가 엄청 짧 고 세로 만 긴 기형 같 아서 고민 이 네요 ㅠㅠ 1.6012189997355881
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.5737502370682084
# 전 아 트릭스 만족 하 면 쓰 고 있 어요 사무실 에서 멀 독 에 키보드 마우스 모니터 연결 해서 인터넷 게임 카톡 전화 노래 등등 좋 아요 ㅎㅎ 1.5434802061768715
# 저 도 갤 투 쓸 때 갤 투문 자음 은 빼 놨었 는데 길거리 에서 들려오 는 휘파람 소리 문자 음 이 너무 탐나 더라구요 ㅠ 1.5292815088880631
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.4983307327368822
# 을 발견 했 습니다 전원 버튼 누르 면서 스카 이 로고 멀티 테스 킹 누르 면 스크린 샷 기능 되 네요 ㅋㅋ 신기 함 니더 1.495796851482476
# 밝 기 낮추 면 더 침침 해 지 는 느낌 이 들 어 항상 밝기 오 십 이상 으로 쓰 네요 다른 폰 들 도 밝 게 썼었 어요 1.4850135797817245
# 저 랑 비슷 하 시 네요 ㅋㅋ 저 도 시리우스 만 기다리 면서 계속 새로 고침 이러 다가 갑자기 훅 나왔 다 사리 질지 도 모른다는 불안 감 ㅠㅠ 1.4810289141311113
# 갠 적 으로 액정 필름 외 엔 케이스 를 안 끼우 는 스타일 이 라 ㅠㅠ 그냥 배터리 뒷 커버 만 하이퍼 스킨 이거 안 파나 요 ㅠㅠ 1.477375578119584
#
#
# ##### OS
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.556047841238661
# 삼성 공돌이 들 의 염원 이 담긴 엑시노스 A 7 이나 A 5 나 사용 된 칩셋 의 원 소스 는 동일 한데 벤치 보 면 은근 벌어지 는 군요 1.5184740007502473
# 하긴 지금 삼성 애플 두 기업 의 네임 밸류 가 지나치 게 높 다 보 니 시장 이 양극 화 되 는 문제 도 있 죠 ㅋㅋ 1.4793220078804372
# 논란 을 일부러 원한다 그분 의 행위 엔 범인 이 모르 는 깊 은 뜻 이 있 다는 건지 요즘 엔 삼성 도 종교 가 되 었 나 봅니다 1.4712560926479723
# aP 근소 한 차이 가 아닙니다 클럭 은 2 0 0 메 mhz 밖에 차이 가 안 나 지만 칩셋 자체 가 틀려요 ex 가 압도 적 입니다 1.4615308854040916
# 하긴 광고 도 참 동화 적 이 고 정적 이 라서 요란 한 녀석 들 에게 묻히 는 경향 도 있 는 거 같 아요 마케팅 시대 라 역시 1.4524966668126786
# 국내 언론 의 보도 와 는 완전히 상반 되 는 결과 네요 애플 망 한다던 글 많이 보이 던데 역시 국내 만 큰 거 찾 나 보 네요 1.444640168505235
# 헐 지금 쓰 고 있 는 폰 도 9 2 6 메가 인데 어떻게 차세대 삼성 을 대표 하 는 폰 의 램 이 7 8 0 메 가래 1.4443216618170953
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.442336370569377
# 이번 에 iPhone 5 를 구입 했 는데 전자파 가 많이 나온다 네요 정말로 많이 나옵니까 그렇 다면 저 는 다른 폰 으로 바꿀려구 요 ㅠㅠ 1.440216464503296
#
#
# ##### 색
# 액정 큰 거 야 다른 안 드 폰 도 크 고 갤 3 가 좋 은 건 아몰레드 의 리얼 블랙 정도 너무 오바 하 시 는 듯 ㅋ 1.5601853783051387
# 갠 적 으로 액정 필름 외 엔 케이스 를 안 끼우 는 스타일 이 라 ㅠㅠ 그냥 배터리 뒷 커버 만 하이퍼 스킨 이거 안 파나 요 ㅠㅠ 1.5376087318099863
# 둥근 모서리 부분 의 회 번 률 이 라고 하 나요 이게 일치 한다고 카피 인정 한 게 겔 스 죠 갤 삼 은 곡선 반경 다른 듯 1.5236414009707153
# 하긴 광고 도 참 동화 적 이 고 정적 이 라서 요란 한 녀석 들 에게 묻히 는 경향 도 있 는 거 같 아요 마케팅 시대 라 역시 1.5011574108340084
# 카메라 는 알파 부터 확실히 우위 였 죠 센서 크롭 ois 의 부제 만 빼 면 노트 4 와 거의 같 은 스펙 에 품질 도 1.4946230808449987
# 아이폰 4 와 가로길이 가 사진 상 으론 비슷 해 보여서 비교 좀 부탁드릴께요 ㅠㅠㅠㅠ 가로 가 엄청 짧 고 세로 만 긴 기형 같 아서 고민 이 네요 ㅠㅠ 1.482158320843853
# 논란 을 일부러 원한다 그분 의 행위 엔 범인 이 모르 는 깊 은 뜻 이 있 다는 건지 요즘 엔 삼성 도 종교 가 되 었 나 봅니다 1.4698734306244796
# 이름 을 멍이 라고 붙여서 그렇 지 멍 이 랑 은 다르 죠 카메라 렌즈 와 광원 에 대한 이해 가 없 으니 발생 하 는 일 이 라고 봅니다 1.453318970270306
# 네 넹 베 가레 이 서 젤 첨 에 나와서 이병헌 이 타이어 굴리 는 CF 찍 고 갤 S 2 랑 경쟁 했 던 그 베가 레이서 요 ㅋ 1.438878557258937
# 저 랑 비슷 하 시 네요 ㅋㅋ 저 도 시리우스 만 기다리 면서 계속 새로 고침 이러 다가 갑자기 훅 나왔 다 사리 질지 도 모른다는 불안 감 ㅠㅠ 1.4366592113393584
# c:\python37\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
